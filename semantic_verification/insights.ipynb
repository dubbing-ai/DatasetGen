# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import numpy as np
import torch

# %% [markdown]
# # Load Data

# %%
import pickle

with open("pickled/cosine_similarities.pkl", "rb") as f:
    cosine_similarities = pickle.load(f)
with open("pickled/embeddings_bge-m3.pkl", "rb") as f:
    np_encoded_texts = pickle.load(f)

# %%
generated_path = "../generated/processed/combined_sentences_with_phoneme.csv"
df = pd.read_csv(generated_path)

# %% [markdown]
# # Binning

# %%
sorted_cosine_similarities = sorted(cosine_similarities.items(), key=lambda x: x[1], reverse=True)

# do binning
bins = np.linspace(0, 1, 11)
bin_counts = np.zeros(10, dtype=int)
for _, cosine_sim in tqdm(sorted_cosine_similarities):
    for i in range(10):
        if cosine_sim < bins[i + 1]:
            bin_counts[i] += 1
            break
# Out:
# 100%|██████████| 2049300/2049300 [00:04<00:00, 417601.50it/s]

# %%
print(bin_counts)
# Out:
# [      0       0       0       0       1   56325 1508419  457234   25191
#     2120]

# %%
with open("results/bin_result.txt", "w") as f:
    for i, count in enumerate(bin_counts):
        f.write(f"Bin {i}: {count}\n")

# %% [markdown]
# # Thresholding

# %%
threshold = 0.9
cos_sims, line1, sent1, line2, sent2 = [], [], [], [], []
for (i, j), cosine_sim in sorted_cosine_similarities:
    if cosine_sim < threshold:
        break
    print(f"Cosine similarity: {cosine_sim:.2f}")
    print(f"Line {i+2}: {df.iloc[i]['thai sentence']}")
    print(f"Line {j+2}: {df.iloc[j]['thai sentence']}")
    print()
    cos_sims.append(round(cosine_sim, 3))
    line1.append(i+2)
    line2.append(j+2)
    sent1.append(df.iloc[i]['thai sentence'])
    sent2.append(df.iloc[j]['thai sentence'])
df_sim = pd.DataFrame({"cosine similarity": cos_sims, "line1": line1, "sentence1": sent1, "line2": line2, "sentence2": sent2})
df_sim.to_csv("results/cosine_similarities.csv", index=False)
# Out:
# Cosine similarity: 1.00
# Line 460: ถ้าเราไม่ลอง เราก็จะไม่รู้ว่าผลลัพธ์จะเป็นอย่างไร
# Line 871: ถ้าเราไม่ลอง เราก็จะไม่รู้ว่าผลลัพธ์จะเป็นอย่างไร
#
# Cosine similarity: 1.00
# Line 810: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 1596: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 1.00
# Line 850: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1018: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 306: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
# Line 636: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
#
# Cosine similarity: 1.00
# Line 431: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 1602: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 1.00
# Line 709: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
# Line 1287: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 1.00
# Line 832: คุณคิดว่าอนาคตของเทคโนโลยีจะเป็นอย่างไร
# Line 2026: คุณคิดว่าอนาคตของเทคโนโลยีจะเป็นอย่างไร
#
# Cosine similarity: 1.00
# Line 1153: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 1709: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1153: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 1977: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1709: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 1977: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 1741: ฉันหวังว่าเราจะมีโอกาสได้ทำงานร่วมกันอีกในอนาคต
#
# Cosine similarity: 1.00
# Line 869: ฉันกำลังมองหาของขวัญที่พิเศษสำหรับวันเกิดของแม่
# Line 1666: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 1.00
# Line 564: ถ้าคุณมีเวลาว่างสุดสัปดาห์นี้ เราไปเดินเล่นที่สวนสาธารณะกันไหม
# Line 1217: ถ้าคุณมีเวลาว่างในสุดสัปดาห์นี้ เราไปเดินเล่นที่สวนสาธารณะกันไหม
#
# Cosine similarity: 1.00
# Line 159: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 359: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
#
# Cosine similarity: 1.00
# Line 850: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1554: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 1018: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1554: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 229: คุณสนใจที่จะเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
# Line 484: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
#
# Cosine similarity: 1.00
# Line 420: เมื่อวานนี้ฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานาน
# Line 764: เมื่อวานฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานานมาก
#
# Cosine similarity: 1.00
# Line 420: เมื่อวานนี้ฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานาน
# Line 1769: เมื่อวานนี้ฉันพบเพื่อนเก่าที่ไม่ได้เจอกันมานานมากแล้ว
#
# Cosine similarity: 1.00
# Line 1153: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 1583: ฉันรู้สึกตื่นเต้นมากที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1583: ฉันรู้สึกตื่นเต้นมากที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 1709: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1583: ฉันรู้สึกตื่นเต้นมากที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 1977: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 764: เมื่อวานฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานานมาก
# Line 1769: เมื่อวานนี้ฉันพบเพื่อนเก่าที่ไม่ได้เจอกันมานานมากแล้ว
#
# Cosine similarity: 1.00
# Line 399: ฉันเคยไปญี่ปุ่นเมื่อปีที่แล้วและประทับใจในวัฒนธรรมของเขา
# Line 1748: ฉันเคยไปญี่ปุ่นเมื่อปีที่แล้วและประทับใจในวัฒนธรรมของเขามาก
#
# Cosine similarity: 1.00
# Line 1107: เมื่อวานนี้ฉันได้พบเพื่อนเก่าที่ไม่ได้เจอกันนานมาก
# Line 1769: เมื่อวานนี้ฉันพบเพื่อนเก่าที่ไม่ได้เจอกันมานานมากแล้ว
#
# Cosine similarity: 1.00
# Line 115: การออกกำลังกายเป็นประจำช่วยให้สุขภาพแข็งแรงและจิตใจสดใส
# Line 296: การออกกำลังกายเป็นประจำจะช่วยให้สุขภาพแข็งแรงและจิตใจสดใส
#
# Cosine similarity: 1.00
# Line 584: ถ้าเราออกเดินทางตอนนี้ เราจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
# Line 1014: ถ้าเราออกเดินทางตอนนี้ เราจะไปถึงจุดหมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 1.00
# Line 685: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 1.00
# Line 404: ฉันกำลังหัดเล่นกีตาร์ แต่ยังไม่เก่งเท่าไหร่
# Line 1657: ฉันกำลังหัดเล่นกีตาร์ แต่ยังไม่ค่อยเก่งเท่าไหร่
#
# Cosine similarity: 1.00
# Line 42: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญ ที่จะทำให้เราเติบโตและพัฒนา
# Line 534: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญที่ช่วยให้เราเติบโตและพัฒนา
#
# Cosine similarity: 1.00
# Line 680: เราควรรักษาสิ่งแวดล้อม เพื่ออนาคตของลูกหลานของเรา
# Line 807: เราควรจะรักษาสิ่งแวดล้อมเพื่ออนาคตของลูกหลาน
#
# Cosine similarity: 1.00
# Line 765: ฉันอยากเรียนรู้วิธีการถ่ายภาพให้สวยงามมากขึ้น
# Line 1601: ฉันอยากเรียนรู้วิธีการถ่ายภาพให้สวยงามกว่าเดิม
#
# Cosine similarity: 1.00
# Line 884: เขากำลังวางแผนที่จะเรียนต่อในระดับปริญญาโทที่ต่างประเทศ
# Line 1155: เขากำลังวางแผนที่จะเรียนต่อปริญญาโทในต่างประเทศ
#
# Cosine similarity: 1.00
# Line 420: เมื่อวานนี้ฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานาน
# Line 1107: เมื่อวานนี้ฉันได้พบเพื่อนเก่าที่ไม่ได้เจอกันนานมาก
#
# Cosine similarity: 1.00
# Line 764: เมื่อวานฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานานมาก
# Line 1107: เมื่อวานนี้ฉันได้พบเพื่อนเก่าที่ไม่ได้เจอกันนานมาก
#
# Cosine similarity: 1.00
# Line 450: ถ้าอากาศดีสุดสัปดาห์นี้ เราไปปิกนิกกันไหม?
# Line 1672: ถ้าอากาศดีสุดสัปดาห์นี้ เราไปปิกนิกกันไหม
#
# Cosine similarity: 1.00
# Line 1130: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
# Line 1554: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 572: ฉันต้องการซื้อของขวัญให้แม่ แต่ยังไม่แน่ใจว่าจะเลือกอะไรดี
# Line 758: ฉันต้องการซื้อของขวัญให้แม่แต่ยังไม่รู้จะเลือกอะไรดี
#
# Cosine similarity: 1.00
# Line 277: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 563: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
#
# Cosine similarity: 1.00
# Line 32: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีอะไรแนะนำไหม
# Line 1233: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีคำแนะนำไหม
#
# Cosine similarity: 1.00
# Line 704: เราควรเคารพความคิดเห็นของผู้อื่น แม้ว่าเราจะไม่เห็นด้วยก็ตาม
# Line 1992: เราควรเคารพความคิดเห็นของผู้อื่นแม้ว่าเราจะไม่เห็นด้วย
#
# Cosine similarity: 1.00
# Line 78: ถ้าเรารู้จักการจัดลำดับความสำคัญ เราก็จะบริหารเวลาได้อย่างมีประสิทธิภาพ
# Line 560: ถ้าเรารู้จักการจัดลำดับความสำคัญ เราก็จะสามารถบริหารเวลาได้อย่างมีประสิทธิภาพ
#
# Cosine similarity: 1.00
# Line 1439: เมื่อวานนี้ฉันไปหาหมอฟัน เพราะปวดฟันมาหลายวันแล้ว
# Line 1863: เมื่อวานนี้ฉันจึงไปพบหมอฟันเพราะปวดฟันมาหลายวันแล้ว
#
# Cosine similarity: 1.00
# Line 152: การอ่านข่าวทุกวันทำให้เราทันเหตุการณ์และรอบรู้มากขึ้น
# Line 346: การอ่านข่าวทุกวันจะช่วยให้เราทันเหตุการณ์และรอบรู้มากขึ้น
#
# Cosine similarity: 1.00
# Line 159: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 918: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
#
# Cosine similarity: 1.00
# Line 287: ฉันชอบฟังเพลงเวลาขับรถ เพราะทำให้การเดินทางสนุกสนานขึ้น
# Line 1664: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางสนุกขึ้น
#
# Cosine similarity: 1.00
# Line 850: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1130: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 1018: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1130: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 484: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
# Line 2002: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือเปล่า
#
# Cosine similarity: 1.00
# Line 1592: ฉันหวังว่าอากาศจะดีในวันหยุด เพื่อที่เราจะได้ไปปิกนิก
# Line 1823: ฉันหวังว่าอากาศจะดีในวันหยุดนี้เพื่อที่เราจะได้ไปปิกนิกกัน
#
# Cosine similarity: 1.00
# Line 1619: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้อีกในอนาคต
# Line 1741: ฉันหวังว่าเราจะมีโอกาสได้ทำงานร่วมกันอีกในอนาคต
#
# Cosine similarity: 1.00
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 1619: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้อีกในอนาคต
#
# Cosine similarity: 1.00
# Line 477: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจในชุมชน
# Line 1328: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อช่วยเศรษฐกิจของชุมชน
#
# Cosine similarity: 1.00
# Line 10: หากเราวางแผนการเดินทางล่วงหน้า เราจะสามารถประหยัดค่าใช้จ่ายและเวลาได้มากขึ้น
# Line 648: หากเราวางแผนการเดินทางล่วงหน้า เราจะสามารถประหยัดทั้งเวลาและเงินได้มากขึ้น
#
# Cosine similarity: 0.99
# Line 359: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 918: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
#
# Cosine similarity: 0.99
# Line 1127: ฉันต้องการซื้อของขวัญให้เพื่อนแต่ยังไม่รู้ว่าจะซื้ออะไรดี
# Line 1720: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่รู้ว่าจะเลือกอะไรดี
#
# Cosine similarity: 0.99
# Line 229: คุณสนใจที่จะเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
# Line 2002: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือเปล่า
#
# Cosine similarity: 0.99
# Line 1803: ฉันรู้สึกขอบคุณสำหรับทุกสิ่งที่ฉันมีในชีวิต
# Line 2021: ฉันรู้สึกขอบคุณสำหรับทุกสิ่งที่มีในชีวิต
#
# Cosine similarity: 0.99
# Line 70: ฉันชอบเดินทางด้วยรถไฟ เพราะได้เห็นวิวทิวทัศน์สวยงามระหว่างทาง
# Line 1050: ฉันชอบเดินทางด้วยรถไฟ เพราะได้ชมวิวทิวทัศน์สวยงาม
#
# Cosine similarity: 0.99
# Line 1342: แม้ว่าฝนจะตกหนัก แต่พวกเราก็ยังต้องออกไปทำงานตามปกติ
# Line 1435: แม้ว่าฝนจะตกหนัก แต่พวกเราก็ต้องไปทำงานตามปกติ
#
# Cosine similarity: 0.99
# Line 786: ฉันอยากลองทำอาหารสูตรใหม่ที่เห็นในอินเตอร์เน็ต
# Line 1203: ฉันอยากลองทำอาหารสูตรใหม่ที่พบในอินเทอร์เน็ต
#
# Cosine similarity: 0.99
# Line 1746: ตอนนี้ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำให้ครอบครัวทาน
# Line 1929: ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำอาหารให้ครอบครัวทาน
#
# Cosine similarity: 0.99
# Line 440: คุณสามารถแนะนำสถานที่ท่องเที่ยวที่น่าสนใจในเมืองนี้ได้ไหม?
# Line 1184: คุณสามารถแนะนำสถานที่ท่องเที่ยวที่น่าสนใจในเมืองนี้ได้ไหม
#
# Cosine similarity: 0.99
# Line 1181: ถ้าเราประหยัดเงินเราก็สามารถไปเที่ยวต่างประเทศได้
# Line 1578: ถ้าเราประหยัดเงินได้มากพอ เราสามารถไปเที่ยวต่างประเทศได้
#
# Cosine similarity: 0.99
# Line 1904: วันนี้อากาศร้อนมาก แต่ลมก็พัดโผนมาให้รู้สึกเย็นขึ้น
# Line 1914: วันนี้อากาศร้อนมาก แต่ลมก็พัดมาให้รู้สึกเย็นขึ้นหน่อย
#
# Cosine similarity: 0.99
# Line 530: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
# Line 726: การฟังเพลงคลาสสิกช่วยให้ฉันสงบและมีสมาธิในการทำงาน
#
# Cosine similarity: 0.99
# Line 652: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
# Line 1266: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.99
# Line 1280: การวางแผนล่วงหน้าช่วยให้เราจัดการเวลาได้มีประสิทธิภาพมากขึ้น
# Line 1584: การวางแผนล่วงหน้าช่วยให้เราจัดการเวลาได้ดีขึ้น
#
# Cosine similarity: 0.99
# Line 709: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
# Line 1040: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีม
#
# Cosine similarity: 0.99
# Line 1040: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีม
# Line 1287: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.99
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 1330: ฉันหวังว่าเราจะมีโอกาสได้ร่วมงานกันอีกในอนาคต
#
# Cosine similarity: 0.99
# Line 1330: ฉันหวังว่าเราจะมีโอกาสได้ร่วมงานกันอีกในอนาคต
# Line 1741: ฉันหวังว่าเราจะมีโอกาสได้ทำงานร่วมกันอีกในอนาคต
#
# Cosine similarity: 0.99
# Line 1682: เราควรปลูกต้นไม้เพิ่ม เพื่อทำให้สิ่งแวดล้อมดีขึ้น
# Line 1947: เราควรปลูกต้นไม้มากขึ้นเพื่อสิ่งแวดล้อมที่ดี
#
# Cosine similarity: 0.99
# Line 33: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
# Line 302: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็รู้สึกดีที่ได้ช่วยเหลือผู้อื่น
#
# Cosine similarity: 0.99
# Line 719: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นอยู่เสมอ
# Line 1182: เขาเป็นคนที่ใจดีและมักจะช่วยเหลือผู้อื่นเสมอ
#
# Cosine similarity: 0.99
# Line 1036: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.99
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
# Line 1790: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.99
# Line 685: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 1036: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
#
# Cosine similarity: 0.99
# Line 726: การฟังเพลงคลาสสิกช่วยให้ฉันสงบและมีสมาธิในการทำงาน
# Line 1090: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.99
# Line 719: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นอยู่เสมอ
# Line 860: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นเสมอเมื่อมีโอกาส
#
# Cosine similarity: 0.99
# Line 559: ฉันชอบการฟังเสียงฝนตก เพราะมันทำให้ฉันรู้สึกสงบและผ่อนคลาย
# Line 1703: ฉันชอบฟังเสียงฝนตก มันทำให้ฉันรู้สึกสงบ
#
# Cosine similarity: 0.99
# Line 1136: เราควรออกกำลังกายเป็นประจำเพื่อสุขภาพที่ดี
# Line 1936: เราควรออกกำลังกายเป็นประจำเพื่อสุขภาพที่แข็งแรง
#
# Cosine similarity: 0.99
# Line 127: เมื่อถึงฤดูหนาว อากาศจะเย็นลงและใบไม้จะเปลี่ยนสี
# Line 699: เมื่อฤดูหนาวมาเยือน อากาศก็เย็นลงและใบไม้ก็เริ่มเปลี่ยนสี
#
# Cosine similarity: 0.99
# Line 563: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
# Line 1643: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 1116: แมวของฉันชอบนอนริมหน้าต่างที่มีแสงแดดส่องถึง
# Line 1928: แมวของฉันชอบนอนอยู่ข้างหน้าต่างเพื่อรับแสงแดด
#
# Cosine similarity: 0.99
# Line 685: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 1790: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.99
# Line 315: การทำงานเป็นทีมจะทำให้เราสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 885: ถ้าเราทำงานเป็นทีม เราจะสามารถบรรลุเป้าหมายได้เร็วขึ้น
#
# Cosine similarity: 0.99
# Line 160: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดี
# Line 810: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.99
# Line 160: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดี
# Line 1596: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.99
# Line 785: เขาเป็นคนตลกและทำให้ทุกคนหัวเราะได้เสมอ
# Line 1146: เขาเป็นคนตลกและมักจะทำให้ทุกคนหัวเราะ
#
# Cosine similarity: 0.99
# Line 1474: หลังจากออกกำลังกาย ฉันรู้สึกสดชื่นขึ้นมาก
# Line 1654: หลังจากที่ฉันออกกำลังกายเสร็จ ฉันรู้สึกสดชื่นมาก
#
# Cosine similarity: 0.99
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 850: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1018: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 631: แม้ว่างานจะยาก แต่ฉันก็จะทำให้ดีที่สุดเท่าที่จะทำได้
# Line 743: ถึงแม้ว่างานจะยาก แต่ฉันก็จะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.99
# Line 32: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีอะไรแนะนำไหม
# Line 869: ฉันกำลังมองหาของขวัญที่พิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 0.99
# Line 1905: เขาทำงานหนักมากจนเหนื่อยโหมไปทั้งตัว
# Line 1918: เขาทำงานหนักมากจนเหนื่อยโผนไปทั้งตัว
#
# Cosine similarity: 0.99
# Line 438: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 1794: การฟังเพลงโปรดช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
#
# Cosine similarity: 0.99
# Line 271: คุณคิดว่าอะไรคือสิ่งที่ทำให้ชีวิตมีความหมายที่สุด?
# Line 2019: คุณคิดว่าอะไรคือสิ่งที่ทำให้ชีวิตมีความหมาย
#
# Cosine similarity: 0.99
# Line 810: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 1775: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่แข็งแรงขึ้น
#
# Cosine similarity: 0.99
# Line 1596: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 1775: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่แข็งแรงขึ้น
#
# Cosine similarity: 0.99
# Line 277: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 1643: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 1375: แม่ค้าที่ร้านขายของชำมักจะจัดของให้เป็นระเบียบ และติดป้ายราคาชัดเจน
# Line 1412: แม่ค้าที่ร้านขายของชำจัดร้านเป็นระเบียบ และติดป้ายราคาชัดเจน
#
# Cosine similarity: 0.99
# Line 74: ถ้าเราช่วยเหลือผู้อื่น โลกนี้ก็จะน่าอยู่ขึ้นสำหรับทุกคน
# Line 1058: ถ้าเราช่วยเหลือผู้อื่น โลกจะน่าอยู่ยิ่งขึ้น
#
# Cosine similarity: 0.99
# Line 98: ถ้าเรามองโลกในแง่บวก ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
# Line 1305: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
#
# Cosine similarity: 0.99
# Line 1276: ถ้าคุณพร้อมแล้ว เราสามารถเริ่มการประชุมได้ทันที
# Line 1570: ถ้าคุณพร้อมแล้ว เราจะเริ่มประชุมได้ทันที
#
# Cosine similarity: 0.99
# Line 499: แม้ว่างานจะยากและท้าทาย แต่ฉันก็จะพยายามทำให้ดีที่สุดเท่าที่ฉันจะทำได้
# Line 631: แม้ว่างานจะยาก แต่ฉันก็จะทำให้ดีที่สุดเท่าที่จะทำได้
#
# Cosine similarity: 0.99
# Line 1025: ถ้าคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
# Line 1270: หากคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ตลอดเวลา
#
# Cosine similarity: 0.99
# Line 32: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีอะไรแนะนำไหม
# Line 1666: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 0.99
# Line 1358: แม่ค้าที่ร้านขายของชำมักจะจดจำลูกค้าประจำได้ และชอบพูดคุยอย่างเป็นกันเอง
# Line 1389: แม่ค้าที่ร้านขายของชำมักจะจดจำลูกค้าประจำได้ และทักทายอย่างเป็นกันเอง
#
# Cosine similarity: 0.99
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1554: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 0.98
# Line 160: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดี
# Line 1775: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่แข็งแรงขึ้น
#
# Cosine similarity: 0.98
# Line 530: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
# Line 1090: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.98
# Line 757: เมื่อไหร่ที่คุณพร้อม เราจะเริ่มประชุมได้ทันที
# Line 1570: ถ้าคุณพร้อมแล้ว เราจะเริ่มประชุมได้ทันที
#
# Cosine similarity: 0.98
# Line 1259: เธอกำลังฝึกเล่นกีตาร์เพื่อแสดงในงานคอนเสิร์ตของโรงเรียน
# Line 1966: เธอกำลังฝึกเล่นกีตาร์เพื่อแสดงในงานโรงเรียน
#
# Cosine similarity: 0.98
# Line 874: ฉันชอบไปเดินเล่นริมชายหาดเพื่อฟังเสียงคลื่นและสัมผัสลมทะเล
# Line 1736: ฉันชอบเดินเล่นริมชายหาด และฟังเสียงคลื่นทะเล
#
# Cosine similarity: 0.98
# Line 1330: ฉันหวังว่าเราจะมีโอกาสได้ร่วมงานกันอีกในอนาคต
# Line 1619: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้อีกในอนาคต
#
# Cosine similarity: 0.98
# Line 146: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 624: ถ้าเราวางแผนการเงินอย่างดี เราจะมีความมั่นคงในอนาคต
#
# Cosine similarity: 0.98
# Line 711: ฉันกำลังเรียนรู้วิธีการถ่ายภาพ เพื่อที่จะเก็บความทรงจำที่สวยงาม
# Line 1068: ฉันอยากเรียนรู้วิธีถ่ายภาพ เพื่อเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.98
# Line 578: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
# Line 1219: ฉันชอบฟังเพลงขณะทำงานเพราะมันช่วยให้ฉันมีสมาธิมากขึ้น
#
# Cosine similarity: 0.98
# Line 340: ถ้าเราใส่ใจสุขภาพ เราก็จะมีชีวิตที่ยืนยาวและมีความสุข
# Line 2001: ถ้าเราดูแลสุขภาพให้ดี เราจะมีชีวิตที่ยืนยาวและมีความสุข
#
# Cosine similarity: 0.98
# Line 1353: แม่ค้าที่ร้านผลไม้มักจะคัดผลไม้อย่างดี และขายในราคาที่เป็นธรรม
# Line 1363: แม่ค้าที่ขายผลไม้มักจะคัดเลือกผลไม้อย่างดี แต่ขายในราคาที่เป็นธรรม
#
# Cosine similarity: 0.98
# Line 869: ฉันกำลังมองหาของขวัญที่พิเศษสำหรับวันเกิดของแม่
# Line 1233: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีคำแนะนำไหม
#
# Cosine similarity: 0.98
# Line 167: การใช้เวลาร่วมกับครอบครัวเป็นสิ่งที่มีคุณค่าและสำคัญมาก
# Line 1293: การใช้เวลาคุณภาพกับครอบครัวเป็นสิ่งที่มีค่าและสำคัญมาก
#
# Cosine similarity: 0.98
# Line 1036: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
# Line 1790: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.98
# Line 1362: คุณครูวิทยาศาสตร์สอนให้เรารู้จักสังเกตธรรมชาติ และทำการทดลองอย่างระมัดระวัง
# Line 1388: คุณครูวิทยาศาสตร์สอนให้เรารู้จักสังเกตธรรมชาติ และทำการทดลองอย่างปลอดภัย
#
# Cosine similarity: 0.98
# Line 481: การสื่อสารที่ดีเป็นสิ่งสำคัญในการทำงานเป็นทีม
# Line 1040: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีม
#
# Cosine similarity: 0.98
# Line 701: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 1638: การทำงานร่วมกันทำให้เราบรรลุเป้าหมายได้เร็วขึ้น
#
# Cosine similarity: 0.98
# Line 1052: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
# Line 1266: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.98
# Line 1233: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีคำแนะนำไหม
# Line 1666: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 0.98
# Line 153: เธอกำลังฝึกซ้อมอย่างหนักเพื่อการแข่งขันที่จะมาถึง
# Line 925: เธอกำลังฝึกซ้อมเพื่อการแข่งขันครั้งสำคัญที่กำลังจะมาถึง
#
# Cosine similarity: 0.98
# Line 94: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิและทำงานได้มีประสิทธิภาพมากขึ้น
# Line 1090: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.98
# Line 615: ถ้าเราร่วมมือกัน เราจะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 701: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
#
# Cosine similarity: 0.98
# Line 584: ถ้าเราออกเดินทางตอนนี้ เราจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
# Line 1923: ถ้าเรารีบออกเดินทางตอนนี้ เราอาจจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.98
# Line 862: ฉันเชื่อว่าความพยายามและความอดทนจะนำพาเราไปสู่ความสำเร็จ
# Line 1795: ฉันเชื่อว่าความพยายามและความตั้งใจจะนำพาเราไปสู่ความสำเร็จ
#
# Cosine similarity: 0.98
# Line 306: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
# Line 1808: ถ้าเรารักษาสิ่งแวดล้อมโลกของเราก็จะน่าอยู่มากขึ้น
#
# Cosine similarity: 0.98
# Line 636: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
# Line 1808: ถ้าเรารักษาสิ่งแวดล้อมโลกของเราก็จะน่าอยู่มากขึ้น
#
# Cosine similarity: 0.98
# Line 949: แม้ว่าจะเหนื่อย แต่เธอก็ยังพยายามทำงานต่อไปโดยไม่ย่อท้อ
# Line 981: แม้ว่าจะเหนื่อย แต่เธอก็ไม่เคยท้อถอยกับการทำงาน
#
# Cosine similarity: 0.98
# Line 775: เขากำลังฝึกฝนอย่างหนักเพื่อเตรียมตัวสำหรับการแข่งขัน
# Line 1171: เขากำลังฝึกซ้อมอย่างหนักเพื่อการแข่งขันครั้งสำคัญ
#
# Cosine similarity: 0.98
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1130: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 0.98
# Line 584: ถ้าเราออกเดินทางตอนนี้ เราจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
# Line 741: ถ้าเราออกเดินทางตอนนี้ เราน่าจะไปถึงก่อนพระอาทิตย์ตก
#
# Cosine similarity: 0.98
# Line 652: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
# Line 1052: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 775: เขากำลังฝึกฝนอย่างหนักเพื่อเตรียมตัวสำหรับการแข่งขัน
# Line 1022: เขากำลังฝึกซ้อมอย่างหนัก เพื่อเตรียมตัวสำหรับการแข่งขันครั้งต่อไป
#
# Cosine similarity: 0.98
# Line 294: ถ้าเราประหยัดเงินวันนี้ อนาคตเราก็จะมีความมั่นคงทางการเงิน
# Line 1770: ถ้าเราประหยัดเงินตั้งแต่วันนี้อนาคตเราจะมีความมั่นคงขึ้น
#
# Cosine similarity: 0.98
# Line 961: ร้านบล็อกเชนคาเฟ่แห่งนี้มีการตกแต่งที่ทันสมัยและน่าสนใจมาก
# Line 987: ร้านบล็อกเชนคาเฟ่นี้มีบรรยากาศที่ทันสมัยและน่าสนใจ
#
# Cosine similarity: 0.98
# Line 202: คุณมีแผนอะไรสำหรับวันหยุดยาวที่กำลังจะมาถึง?
# Line 429: คุณวางแผนจะทำอะไรในวันหยุดยาวที่จะถึงนี้?
#
# Cosine similarity: 0.98
# Line 438: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 1998: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่เหน็ดเหนื่อย
#
# Cosine similarity: 0.98
# Line 431: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 1721: ถ้าเราทำงานร่วมกัน เราจะสามารถทำงานนี้ให้เสร็จเร็วขึ้น
#
# Cosine similarity: 0.98
# Line 1602: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 1721: ถ้าเราทำงานร่วมกัน เราจะสามารถทำงานนี้ให้เสร็จเร็วขึ้น
#
# Cosine similarity: 0.98
# Line 1162: ฉันต้องการเวลาสักครู่เพื่อคิดเกี่ยวกับข้อเสนอของคุณ
# Line 1275: ฉันต้องการเวลาในการคิดเกี่ยวกับข้อเสนอนี้สักหน่อย
#
# Cosine similarity: 0.98
# Line 907: เธอมีความฝันที่จะเป็นนักเขียนและกำลังเขียนหนังสือเล่มแรกของเธอ
# Line 1057: เธอฝันอยากเป็นนักเขียนและกำลังเริ่มเขียนนิยายเล่มแรก
#
# Cosine similarity: 0.98
# Line 936: เมื่อเราเปิดใจรับฟังผู้อื่น เราก็จะเรียนรู้มากขึ้น
# Line 1061: เมื่อเราเปิดใจรับฟังความคิดเห็นของผู้อื่น เราจะเรียนรู้มากขึ้น
#
# Cosine similarity: 0.98
# Line 741: ถ้าเราออกเดินทางตอนนี้ เราน่าจะไปถึงก่อนพระอาทิตย์ตก
# Line 1014: ถ้าเราออกเดินทางตอนนี้ เราจะไปถึงจุดหมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.98
# Line 277: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 1113: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.98
# Line 446: วันนี้ฉันลืมกุญแจบ้านไว้ที่ทำงาน ต้องกลับไปเอา
# Line 651: ฉันลืมกุญแจบ้านไว้ที่ทำงาน ทำให้ต้องกลับไปเอาอีกครั้งหนึ่ง
#
# Cosine similarity: 0.98
# Line 563: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
# Line 1113: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.98
# Line 1294: ฉันอยากเรียนรู้การเล่นเปียโน เพราะชอบเสียงเพลงที่ไพเราะ
# Line 1830: ฉันอยากจะเรียนรู้การเล่นเปียโนเพราะชอบเสียงดนตรี
#
# Cosine similarity: 0.98
# Line 499: แม้ว่างานจะยากและท้าทาย แต่ฉันก็จะพยายามทำให้ดีที่สุดเท่าที่ฉันจะทำได้
# Line 743: ถึงแม้ว่างานจะยาก แต่ฉันก็จะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.98
# Line 860: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นเสมอเมื่อมีโอกาส
# Line 1182: เขาเป็นคนที่ใจดีและมักจะช่วยเหลือผู้อื่นเสมอ
#
# Cosine similarity: 0.98
# Line 1591: แม้ว่าจะมีอุปสรรคมากมาย เราก็ไม่ควรยอมแพ้
# Line 1719: แม้ว่าจะมีอุปสรรคมากมาย แต่เราจะไม่ยอมแพ้
#
# Cosine similarity: 0.98
# Line 149: เมื่อเรามองโลกในแง่ดี ชีวิตก็จะสดใสและมีความสุขมากขึ้น
# Line 1786: ถ้าเรามองโลกในแง่ดีชีวิตก็จะมีความสุขมากขึ้น
#
# Cosine similarity: 0.98
# Line 638: เราสามารถเรียนรู้จากความผิดพลาดเพื่อพัฒนาตัวเองต่อไป
# Line 1979: เราควรเรียนรู้จากความผิดพลาดเพื่อพัฒนาตนเอง
#
# Cosine similarity: 0.98
# Line 1014: ถ้าเราออกเดินทางตอนนี้ เราจะไปถึงจุดหมายก่อนพระอาทิตย์ตกดิน
# Line 1923: ถ้าเรารีบออกเดินทางตอนนี้ เราอาจจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.98
# Line 359: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1052: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 1249: ฉันอยากเรียนทำอาหารไทยเพื่อที่จะทำให้ครอบครัวทานที่บ้าน
# Line 1929: ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำอาหารให้ครอบครัวทาน
#
# Cosine similarity: 0.98
# Line 918: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
# Line 1052: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 481: การสื่อสารที่ดีเป็นสิ่งสำคัญในการทำงานเป็นทีม
# Line 709: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.98
# Line 481: การสื่อสารที่ดีเป็นสิ่งสำคัญในการทำงานเป็นทีม
# Line 1287: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.98
# Line 146: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 328: การวางแผนการเงินจะช่วยให้เรามีอนาคตที่มั่นคงและปลอดภัย
#
# Cosine similarity: 0.98
# Line 152: การอ่านข่าวทุกวันทำให้เราทันเหตุการณ์และรอบรู้มากขึ้น
# Line 1816: การอ่านข่าวทุกวันช่วยให้เราทันสมัยและรู้ทันเหตุการณ์
#
# Cosine similarity: 0.98
# Line 326: ถ้าเรารับฟังความคิดเห็นของผู้อื่น เราก็จะเข้าใจพวกเขามากขึ้น
# Line 1825: การฟังความคิดเห็นของผู้อื่นจะช่วยให้เราเข้าใจมากขึ้น
#
# Cosine similarity: 0.98
# Line 472: ฉันเชื่อว่าการศึกษาเป็นกุญแจสำคัญสู่ความสำเร็จ
# Line 733: ฉันเชื่อว่าการศึกษาเป็นกุญแจสู่ความสำเร็จในชีวิต
#
# Cosine similarity: 0.98
# Line 822: ฉันชอบฟังเสียงคลื่นทะเลเวลาที่ไปเที่ยวชายหาด
# Line 1736: ฉันชอบเดินเล่นริมชายหาด และฟังเสียงคลื่นทะเล
#
# Cosine similarity: 0.98
# Line 822: ฉันชอบฟังเสียงคลื่นทะเลเวลาที่ไปเที่ยวชายหาด
# Line 1780: ฉันชอบฟังเสียงคลื่นทะเลเวลานั่งพักผ่อนบนชายหาด
#
# Cosine similarity: 0.98
# Line 163: การฟังความคิดเห็นของผู้อื่นทำให้เราเข้าใจและเรียนรู้มากขึ้น
# Line 1825: การฟังความคิดเห็นของผู้อื่นจะช่วยให้เราเข้าใจมากขึ้น
#
# Cosine similarity: 0.98
# Line 159: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1052: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 1151: ผมอยากเรียนรู้ภาษาใหม่เพื่อเปิดโลกทัศน์มากขึ้น
# Line 1961: ฉันชอบเรียนรู้ภาษาใหม่เพื่อเปิดโลกทัศน์ของตัวเอง
#
# Cosine similarity: 0.98
# Line 1201: ผมกำลังหาหนังสือที่ดีสักเล่มเพื่ออ่านในวันหยุด
# Line 1949: ฉันกำลังหาหนังสือเล่มใหม่ที่จะอ่านในวันหยุดนี้
#
# Cosine similarity: 0.98
# Line 278: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกภูมิใจที่ได้ทำงานสำเร็จตามเป้าหมาย
# Line 1551: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกพอใจที่ได้ทำงานสำเร็จ
#
# Cosine similarity: 0.98
# Line 42: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญ ที่จะทำให้เราเติบโตและพัฒนา
# Line 1266: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.98
# Line 2: วันนี้อากาศดีมาก ฉันคิดว่าเราควรออกไปเดินเล่นที่สวนสาธารณะด้วยกันไหม
# Line 1537: วันนี้อากาศดีมาก เราน่าจะไปเดินเล่นที่สวนสาธารณะกันไหม?
#
# Cosine similarity: 0.98
# Line 434: ฉันต้องการฝึกฝนการพูดในที่สาธารณะเพื่อเพิ่มความมั่นใจ
# Line 539: ฉันกำลังฝึกพูดในที่สาธารณะ เพื่อเพิ่มความมั่นใจและทักษะการสื่อสาร
#
# Cosine similarity: 0.98
# Line 1252: แม้ว่าจะมีอุปสรรคมากมาย แต่เราต้องไม่ยอมแพ้และเดินหน้าต่อไป
# Line 1719: แม้ว่าจะมีอุปสรรคมากมาย แต่เราจะไม่ยอมแพ้
#
# Cosine similarity: 0.98
# Line 94: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิและทำงานได้มีประสิทธิภาพมากขึ้น
# Line 726: การฟังเพลงคลาสสิกช่วยให้ฉันสงบและมีสมาธิในการทำงาน
#
# Cosine similarity: 0.98
# Line 19: ฉันอยากเรียนรู้ภาษาใหม่ เพราะจะได้สื่อสารกับคนต่างชาติได้ดีขึ้น
# Line 1653: ฉันเรียนภาษาใหม่ เพราะอยากสื่อสารกับคนต่างชาติ
#
# Cosine similarity: 0.98
# Line 1036: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
# Line 1113: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.98
# Line 606: แม้ว่าจะมีอุปสรรคมากมาย แต่ฉันก็จะไม่ยอมแพ้ต่อความฝันของฉัน
# Line 841: ถึงแม้ว่าจะยากลำบาก แต่ฉันก็จะไม่ยอมแพ้ต่อความฝัน
#
# Cosine similarity: 0.98
# Line 17: ถึงแม้ว่าเราจะพบกับอุปสรรคมากมาย แต่ก็ไม่ควรยอมแพ้และควรสู้ต่อไป
# Line 1591: แม้ว่าจะมีอุปสรรคมากมาย เราก็ไม่ควรยอมแพ้
#
# Cosine similarity: 0.98
# Line 346: การอ่านข่าวทุกวันจะช่วยให้เราทันเหตุการณ์และรอบรู้มากขึ้น
# Line 1816: การอ่านข่าวทุกวันช่วยให้เราทันสมัยและรู้ทันเหตุการณ์
#
# Cosine similarity: 0.98
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 287: ฉันชอบฟังเพลงเวลาขับรถ เพราะทำให้การเดินทางสนุกสนานขึ้น
#
# Cosine similarity: 0.98
# Line 415: การนั่งสมาธิช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิมากขึ้น
# Line 626: ฉันพบว่าการนั่งสมาธิช่วยให้จิตใจสงบและมีสมาธิมากขึ้น
#
# Cosine similarity: 0.98
# Line 534: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญที่ช่วยให้เราเติบโตและพัฒนา
# Line 1266: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 918: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
# Line 1266: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 33: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
# Line 1451: ถึงแม้ว่าจะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
#
# Cosine similarity: 0.97
# Line 159: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1266: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 94: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิและทำงานได้มีประสิทธิภาพมากขึ้น
# Line 530: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
#
# Cosine similarity: 0.97
# Line 1127: ฉันต้องการซื้อของขวัญให้เพื่อนแต่ยังไม่รู้ว่าจะซื้ออะไรดี
# Line 1257: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่แน่ใจว่าเขาจะชอบอะไร
#
# Cosine similarity: 0.97
# Line 1249: ฉันอยากเรียนทำอาหารไทยเพื่อที่จะทำให้ครอบครัวทานที่บ้าน
# Line 1746: ตอนนี้ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำให้ครอบครัวทาน
#
# Cosine similarity: 0.97
# Line 327: ฉันชอบดื่มกาแฟตอนเช้า มันช่วยให้ฉันตื่นตัวและพร้อมสำหรับวันใหม่
# Line 1925: ฉันชอบดื่มกาแฟในตอนเช้าเพราะมันทำให้ฉันตื่นตัว
#
# Cosine similarity: 0.97
# Line 837: เราควรจะสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจของเรา
# Line 1985: พวกเราควรสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจที่ยั่งยืน
#
# Cosine similarity: 0.97
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1664: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางสนุกขึ้น
#
# Cosine similarity: 0.97
# Line 957: คุณหมอแนะนำให้พักผ่อนและไม่ควรโหมงานหนักจนเกินไป
# Line 975: หมอแนะนำว่าไม่ควรโหมงานหนักเกินไป ควรพักผ่อนให้เพียงพอ
#
# Cosine similarity: 0.97
# Line 146: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 1051: การวางแผนทางการเงินที่ดีจะช่วยให้เรามีความมั่นคง
#
# Cosine similarity: 0.97
# Line 359: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1266: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 656: ถึงแม้ว่าเขาจะอายุน้อย แต่เขาก็มีประสบการณ์ในการทำงานมากมาย
# Line 749: แม้ว่าเขาจะอายุน้อย แต่เขาก็มีประสบการณ์มากมาย
#
# Cosine similarity: 0.97
# Line 487: ฉันชอบอ่านหนังสือทุกคืนก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายมากขึ้น
# Line 563: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 1551: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกพอใจที่ได้ทำงานสำเร็จ
# Line 1686: แม้ว่าวันนี้จะยุ่ง แต่ฉันก็รู้สึกมีความสุขที่ได้ทำงาน
#
# Cosine similarity: 0.97
# Line 17: ถึงแม้ว่าเราจะพบกับอุปสรรคมากมาย แต่ก็ไม่ควรยอมแพ้และควรสู้ต่อไป
# Line 1252: แม้ว่าจะมีอุปสรรคมากมาย แต่เราต้องไม่ยอมแพ้และเดินหน้าต่อไป
#
# Cosine similarity: 0.97
# Line 652: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
# Line 918: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
#
# Cosine similarity: 0.97
# Line 1166: ถ้าคุณพร้อมแล้วเราจะเริ่มประชุมกันตอนนี้เลย
# Line 1570: ถ้าคุณพร้อมแล้ว เราจะเริ่มประชุมได้ทันที
#
# Cosine similarity: 0.97
# Line 701: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 1956: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 1813: ถ้าเราช่วยกันรักษาความสะอาดชุมชนของเราก็จะน่าอยู่ขึ้น
# Line 2006: ถ้าเราช่วยกันรักษาความสะอาด สังคมของเราจะน่าอยู่ขึ้น
#
# Cosine similarity: 0.97
# Line 1347: แม่มักจะสอนให้เราประหยัดน้ำประหยัดไฟ และใช้ทรัพยากรอย่างคุ้มค่า
# Line 1384: แม่มักจะสอนให้เรารู้จักประหยัดน้ำประหยัดไฟ และรักษาสิ่งแวดล้อม
#
# Cosine similarity: 0.97
# Line 366: แม้ว่าฉันจะมีงานยุ่ง แต่ฉันก็จะหาเวลาให้ครอบครัวเสมอ
# Line 820: แม้ว่าฉันจะยุ่ง แต่ฉันก็จะหาเวลาให้กับครอบครัว
#
# Cosine similarity: 0.97
# Line 611: ฉันเชื่อว่าการอ่านหนังสือจะเปิดโลกทัศน์และเพิ่มความรู้ให้เรา
# Line 816: ฉันคิดว่าการอ่านหนังสือทำให้เราเปิดโลกทัศน์กว้างขึ้น
#
# Cosine similarity: 0.97
# Line 159: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 652: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 113: เมื่อคืนฝนตกหนักมาก ทำให้ถนนลื่นและต้องขับรถอย่างระมัดระวัง
# Line 565: เมื่อวานนี้ฝนตกหนักมาก ทำให้ถนนลื่นและต้องขับรถอย่างระมัดระวัง
#
# Cosine similarity: 0.97
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 128: การอ่านหนังสือก่อนนอนช่วยให้หลับสบายและฝันดี
#
# Cosine similarity: 0.97
# Line 33: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
# Line 1135: แม้ว่าวันนี้จะยุ่งแต่ฉันก็มีความสุขที่ได้ช่วยเหลือคนอื่น
#
# Cosine similarity: 0.97
# Line 1257: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่แน่ใจว่าเขาจะชอบอะไร
# Line 1720: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่รู้ว่าจะเลือกอะไรดี
#
# Cosine similarity: 0.97
# Line 277: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 487: ฉันชอบอ่านหนังสือทุกคืนก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายมากขึ้น
#
# Cosine similarity: 0.97
# Line 607: ฉันชอบนั่งอ่านหนังสือที่ร้านกาแฟ เพราะบรรยากาศที่เงียบสงบ
# Line 643: ฉันชอบอ่านหนังสือที่ร้านกาแฟ เพราะบรรยากาศเงียบสงบและมีกลิ่นหอมของกาแฟ
#
# Cosine similarity: 0.97
# Line 837: เราควรจะสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจของเรา
# Line 1328: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อช่วยเศรษฐกิจของชุมชน
#
# Cosine similarity: 0.97
# Line 43: ถ้าเรารักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่มากขึ้นสำหรับคนรุ่นต่อไป
# Line 1808: ถ้าเรารักษาสิ่งแวดล้อมโลกของเราก็จะน่าอยู่มากขึ้น
#
# Cosine similarity: 0.97
# Line 1022: เขากำลังฝึกซ้อมอย่างหนัก เพื่อเตรียมตัวสำหรับการแข่งขันครั้งต่อไป
# Line 1171: เขากำลังฝึกซ้อมอย่างหนักเพื่อการแข่งขันครั้งสำคัญ
#
# Cosine similarity: 0.97
# Line 1214: เราควรตรวจสอบข้อมูลอีกครั้งเพื่อความแน่ใจก่อนส่งมอบ
# Line 1594: เราควรตรวจสอบข้อมูลอีกครั้งเพื่อความถูกต้องก่อนส่ง
#
# Cosine similarity: 0.97
# Line 419: ฉันต้องการเรียนรู้การถ่ายภาพเพื่อเก็บความทรงจำที่ดี
# Line 1068: ฉันอยากเรียนรู้วิธีถ่ายภาพ เพื่อเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.97
# Line 533: ถ้าเรามองโลกในแง่ดี ชีวิตของเราก็จะเต็มไปด้วยพลังและความหวัง
# Line 1305: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
#
# Cosine similarity: 0.97
# Line 42: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญ ที่จะทำให้เราเติบโตและพัฒนา
# Line 652: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 26: ฉันตั้งใจว่าจะเริ่มออกกำลังกายทุกเช้า เพื่อสุขภาพที่ดีและร่างกายที่แข็งแรง
# Line 954: ฉันจึงตัดสินใจเริ่มออกกำลังกายทุกเช้า เพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.97
# Line 908: เมื่อเราช่วยเหลือผู้อื่น เราก็จะรู้สึกดีและโลกจะน่าอยู่ขึ้น
# Line 1058: ถ้าเราช่วยเหลือผู้อื่น โลกจะน่าอยู่ยิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 743: ถึงแม้ว่างานจะยาก แต่ฉันก็จะพยายามทำให้ดีที่สุด
# Line 1469: ถึงแม้ว่าจะยาก แต่ฉันจะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.97
# Line 359: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 652: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 377: การเปิดใจรับฟังความคิดเห็นของผู้อื่น จะทำให้เราเติบโตและพัฒนา
# Line 1331: การเปิดใจรับฟังความคิดเห็นที่แตกต่างจะช่วยให้เราเติบโตขึ้น
#
# Cosine similarity: 0.97
# Line 534: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญที่ช่วยให้เราเติบโตและพัฒนา
# Line 652: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 530: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
# Line 1754: ฉันชอบฟังเพลงคลาสสิกเวลาทำงานเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 942: งานนี้ยากกว่าที่คิดไว้มาก แต่ฉันจะพยายามทำให้ดีที่สุดและไม่ย่อท้อ
# Line 968: งานนี้ยากกว่าที่คิดไว้ แต่ฉันจะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.97
# Line 95: ถ้าเราดูแลสิ่งแวดล้อม โลกของเราก็จะสวยงามและยั่งยืนสำหรับคนรุ่นหลัง
# Line 120: เราควรรักษาสิ่งแวดล้อมเพื่อให้โลกของเรายังคงสวยงามสำหรับคนรุ่นหลัง
#
# Cosine similarity: 0.97
# Line 844: เมื่อวานนี้ฝนตกหนักมากแต่ฉันยังคงต้องออกไปทำงานตามปกติ
# Line 1012: แม้ว่าวันนี้ฝนจะตกหนัก แต่ฉันก็ยังต้องไปทำงานตามปกติ
#
# Cosine similarity: 0.97
# Line 1020: ฉันต้องการซื้อของขวัญพิเศษให้กับน้องสาวในวันเกิดของเธอ
# Line 1563: ฉันกำลังมองหาของขวัญวันเกิดที่เหมาะสมสำหรับน้องสาว
#
# Cosine similarity: 0.97
# Line 1447: ถ้าคุณต้องการความช่วยเหลือ คุณสามารถโทรหาฉันได้ตลอดเวลา
# Line 1647: ถ้าเธอต้องการความช่วยเหลือ โปรดโทรหาฉันได้ทุกเวลา
#
# Cosine similarity: 0.97
# Line 1113: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 757: เมื่อไหร่ที่คุณพร้อม เราจะเริ่มประชุมได้ทันที
# Line 1276: ถ้าคุณพร้อมแล้ว เราสามารถเริ่มการประชุมได้ทันที
#
# Cosine similarity: 0.97
# Line 506: การฟังเพลงโปรดระหว่างการทำงาน ช่วยให้ฉันมีสมาธิและทำงานได้อย่างมีประสิทธิภาพ
# Line 578: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 519: ฉันอยากเรียนรู้การถ่ายภาพ เพื่อบันทึกความทรงจำและช่วงเวลาที่สวยงามในชีวิต
# Line 1068: ฉันอยากเรียนรู้วิธีถ่ายภาพ เพื่อเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.97
# Line 866: ถ้าคุณสนใจ เราสามารถจัดการประชุมเพื่อหารือรายละเอียดเพิ่มเติม
# Line 1126: ถ้าคุณสนใจเราสามารถจัดการประชุมเพิ่มเติมได้
#
# Cosine similarity: 0.97
# Line 305: การอ่านหนังสือทำให้เราเปิดใจกว้างและเข้าใจโลกมากขึ้น
# Line 816: ฉันคิดว่าการอ่านหนังสือทำให้เราเปิดโลกทัศน์กว้างขึ้น
#
# Cosine similarity: 0.97
# Line 897: ฉันหวังว่าจะได้พบคุณอีกครั้งในอนาคตอันใกล้นี้
# Line 1023: ฉันหวังว่าเราจะมีโอกาสได้พบกันอีกครั้งในอนาคตอันใกล้นี้
#
# Cosine similarity: 0.97
# Line 437: ถ้าคุณพร้อมแล้ว เราจะออกเดินทางกันตอนนี้เลย
# Line 817: ถ้าคุณพร้อมแล้ว เราจะเริ่มเดินทางกันทันที
#
# Cosine similarity: 0.97
# Line 128: การอ่านหนังสือก่อนนอนช่วยให้หลับสบายและฝันดี
# Line 685: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 506: การฟังเพลงโปรดระหว่างการทำงาน ช่วยให้ฉันมีสมาธิและทำงานได้อย่างมีประสิทธิภาพ
# Line 1219: ฉันชอบฟังเพลงขณะทำงานเพราะมันช่วยให้ฉันมีสมาธิมากขึ้น
#
# Cosine similarity: 0.97
# Line 317: ฉันชอบเดินเล่นริมชายหาด ฟังเสียงคลื่นและสูดอากาศบริสุทธิ์
# Line 874: ฉันชอบไปเดินเล่นริมชายหาดเพื่อฟังเสียงคลื่นและสัมผัสลมทะเล
#
# Cosine similarity: 0.97
# Line 328: การวางแผนการเงินจะช่วยให้เรามีอนาคตที่มั่นคงและปลอดภัย
# Line 624: ถ้าเราวางแผนการเงินอย่างดี เราจะมีความมั่นคงในอนาคต
#
# Cosine similarity: 0.97
# Line 1252: แม้ว่าจะมีอุปสรรคมากมาย แต่เราต้องไม่ยอมแพ้และเดินหน้าต่อไป
# Line 1591: แม้ว่าจะมีอุปสรรคมากมาย เราก็ไม่ควรยอมแพ้
#
# Cosine similarity: 0.97
# Line 685: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 1113: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.97
# Line 1721: ถ้าเราทำงานร่วมกัน เราจะสามารถทำงานนี้ให้เสร็จเร็วขึ้น
# Line 1956: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 284: เมื่อวานนี้ฉันได้ลองทำสูตรอาหารใหม่ และผลลัพธ์ก็ออกมาอร่อยมาก
# Line 430: ฉันลองทำสูตรอาหารใหม่และผลลัพธ์ออกมาอร่อยมาก
#
# Cosine similarity: 0.97
# Line 1332: คุณมีคำแนะนำอย่างไรในการพัฒนาทักษะการสื่อสารของฉัน
# Line 1793: คุณมีคำแนะนำอย่างไรบ้างในการพัฒนาทักษะการสื่อสาร
#
# Cosine similarity: 0.97
# Line 1305: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
# Line 1786: ถ้าเรามองโลกในแง่ดีชีวิตก็จะมีความสุขมากขึ้น
#
# Cosine similarity: 0.97
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 685: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 741: ถ้าเราออกเดินทางตอนนี้ เราน่าจะไปถึงก่อนพระอาทิตย์ตก
# Line 1923: ถ้าเรารีบออกเดินทางตอนนี้ เราอาจจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.97
# Line 563: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 477: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจในชุมชน
# Line 837: เราควรจะสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจของเรา
#
# Cosine similarity: 0.97
# Line 1113: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
# Line 1790: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 328: การวางแผนการเงินจะช่วยให้เรามีอนาคตที่มั่นคงและปลอดภัย
# Line 1609: เราควรวางแผนการเงินให้ดีเพื่ออนาคตที่มั่นคง
#
# Cosine similarity: 0.97
# Line 35: ถ้าคุณต้องการความช่วยเหลือเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
# Line 1025: ถ้าคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
#
# Cosine similarity: 0.97
# Line 598: ถ้าเราแบ่งงานกันทำ เราจะเสร็จเร็วขึ้นและมีเวลาพักผ่อนมากขึ้น
# Line 768: ถ้าเราแบ่งงานกันทำ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.97
# Line 74: ถ้าเราช่วยเหลือผู้อื่น โลกนี้ก็จะน่าอยู่ขึ้นสำหรับทุกคน
# Line 908: เมื่อเราช่วยเหลือผู้อื่น เราก็จะรู้สึกดีและโลกจะน่าอยู่ขึ้น
#
# Cosine similarity: 0.97
# Line 1794: การฟังเพลงโปรดช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 1998: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่เหน็ดเหนื่อย
#
# Cosine similarity: 0.97
# Line 349: ฉันอยากเรียนรู้การเล่นดนตรี เพราะมันเป็นวิธีที่ดีในการแสดงออก
# Line 552: ฉันตั้งใจจะเรียนรู้การเล่นดนตรี เพราะมันเป็นวิธีที่ดีในการแสดงออกและผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 431: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 1956: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 1602: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 1956: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 149: เมื่อเรามองโลกในแง่ดี ชีวิตก็จะสดใสและมีความสุขมากขึ้น
# Line 1305: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
#
# Cosine similarity: 0.97
# Line 799: ฉันกำลังฝึกเล่นโยคะเพื่อสุขภาพกายและใจที่ดีขึ้น
# Line 1812: ฉันกำลังฝึกฝนการเล่นโยคะเพื่อสุขภาพที่ดีและจิตใจที่สงบ
#
# Cosine similarity: 0.97
# Line 624: ถ้าเราวางแผนการเงินอย่างดี เราจะมีความมั่นคงในอนาคต
# Line 1609: เราควรวางแผนการเงินให้ดีเพื่ออนาคตที่มั่นคง
#
# Cosine similarity: 0.97
# Line 146: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 1609: เราควรวางแผนการเงินให้ดีเพื่ออนาคตที่มั่นคง
#
# Cosine similarity: 0.97
# Line 658: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางไม่เหงา
# Line 1664: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางสนุกขึ้น
#
# Cosine similarity: 0.97
# Line 128: การอ่านหนังสือก่อนนอนช่วยให้หลับสบายและฝันดี
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 202: คุณมีแผนอะไรสำหรับวันหยุดยาวที่กำลังจะมาถึง?
# Line 1718: คุณมีแผนสำหรับวันหยุดยาวนี้หรือยัง
#
# Cosine similarity: 0.97
# Line 1148: ถ้ามีปัญหาอะไรคุณสามารถโทรหาฉันได้ตลอดเวลา
# Line 1447: ถ้าคุณต้องการความช่วยเหลือ คุณสามารถโทรหาฉันได้ตลอดเวลา
#
# Cosine similarity: 0.97
# Line 1113: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
# Line 1643: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 141: ฉันตั้งใจว่าจะเรียนภาษาใหม่เพื่อเปิดโอกาสในการทำงานมากขึ้น
# Line 1072: ฉันสนใจที่จะเรียนรู้ภาษาใหม่ เพื่อเปิดโอกาสในงานอาชีพ
#
# Cosine similarity: 0.97
# Line 356: ฉันชอบนั่งอ่านหนังสือในคาเฟ่ มันเป็นบรรยากาศที่ผ่อนคลาย
# Line 607: ฉันชอบนั่งอ่านหนังสือที่ร้านกาแฟ เพราะบรรยากาศที่เงียบสงบ
#
# Cosine similarity: 0.97
# Line 261: คุณมีวิธีการจัดการกับความเครียดอย่างไรบ้าง?
# Line 1579: คุณมีคำแนะนำในการจัดการกับความเครียดไหม?
#
# Cosine similarity: 0.97
# Line 1016: หลังจากที่เราเสร็จงานนี้แล้ว เราควรฉลองด้วยกันสักหน่อยดีไหม
# Line 1733: หลังจากที่เราเสร็จงานนี้แล้ว เรามาฉลองกันเถอะ
#
# Cosine similarity: 0.97
# Line 627: ถ้าเรามีความมุ่งมั่นและความพยายาม เราจะสามารถทำได้ทุกอย่าง
# Line 1730: ถ้าเรามีความตั้งใจ เราจะสามารถทำได้ทุกอย่าง
#
# Cosine similarity: 0.97
# Line 29: ฉันชอบดื่มกาแฟทุกเช้า เพราะมันช่วยให้ฉันตื่นตัวและพร้อมเริ่มงาน
# Line 327: ฉันชอบดื่มกาแฟตอนเช้า มันช่วยให้ฉันตื่นตัวและพร้อมสำหรับวันใหม่
#
# Cosine similarity: 0.97
# Line 277: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 56: เธอเคยลองเล่นโยคะหรือไม่ มันช่วยให้ร่างกายและจิตใจแข็งแรงขึ้น
# Line 1679: เธอเคยลองเล่นโยคะไหม มันช่วยให้ร่างกายและจิตใจผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 1568: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 165: การดูแลต้นไม้และดอกไม้ช่วยให้ฉันรู้สึกผ่อนคลายและมีความสุข
# Line 731: การดูแลต้นไม้และดอกไม้เป็นงานอดิเรกที่ทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 935: ฉันเชื่อว่าความเมตตาและความเอื้อเฟื้อเผื่อแผ่สามารถเปลี่ยนแปลงโลกได้
# Line 2016: ฉันเชื่อว่าความเมตตาสามารถเปลี่ยนแปลงโลกได้
#
# Cosine similarity: 0.97
# Line 419: ฉันต้องการเรียนรู้การถ่ายภาพเพื่อเก็บความทรงจำที่ดี
# Line 711: ฉันกำลังเรียนรู้วิธีการถ่ายภาพ เพื่อที่จะเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.97
# Line 526: ฉันเพิ่งเริ่มฝึกโยคะ และพบว่ามันช่วยให้ฉันมีสุขภาพที่ดีทั้งกายและใจ
# Line 1987: ฉันเพิ่งเริ่มเรียนโยคะและรู้สึกว่ามันดีต่อร่างกายและจิตใจ
#
# Cosine similarity: 0.97
# Line 487: ฉันชอบอ่านหนังสือทุกคืนก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายมากขึ้น
# Line 1643: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 759: ถ้าอากาศดี เราไปปิกนิกที่ชายหาดกันเถอะ
# Line 1019: ถ้าวันนี้อากาศดี เราจะไปปิกนิกที่ชายหาดกันไหม
#
# Cosine similarity: 0.97
# Line 959: มีคนมาร้านเยอะมากในช่วงจัดโปรโมชั่นพิเศษ
# Line 1006: วันนี้มีคนมาร้านเยอะมากเพราะมีโปรโมชั่นพิเศษ
#
# Cosine similarity: 0.97
# Line 18: เมื่อไหร่ที่คุณมีปัญหา สามารถปรึกษาฉันได้เสมอ ฉันยินดีที่จะช่วยเหลือ
# Line 1749: ถ้าคุณมีปัญหาอะไรสามารถบอกฉันได้ฉันยินดีช่วยเหลือเสมอ
#
# Cosine similarity: 0.97
# Line 302: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็รู้สึกดีที่ได้ช่วยเหลือผู้อื่น
# Line 1451: ถึงแม้ว่าจะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
#
# Cosine similarity: 0.96
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 1790: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.96
# Line 452: การอ่านข่าวทุกเช้าช่วยให้ฉันรู้เท่าทันสถานการณ์ปัจจุบัน
# Line 723: การอ่านข่าวทุกเช้าทำให้ฉันทันเหตุการณ์และรู้เรื่องราวรอบโลก
#
# Cosine similarity: 0.96
# Line 1793: คุณมีคำแนะนำอย่างไรบ้างในการพัฒนาทักษะการสื่อสาร
# Line 1978: คุณมีคำแนะนำสำหรับการปรับปรุงทักษะการสื่อสารหรือไม่
#
# Cosine similarity: 0.96
# Line 163: การฟังความคิดเห็นของผู้อื่นทำให้เราเข้าใจและเรียนรู้มากขึ้น
# Line 1061: เมื่อเราเปิดใจรับฟังความคิดเห็นของผู้อื่น เราจะเรียนรู้มากขึ้น
#
# Cosine similarity: 0.96
# Line 563: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
# Line 685: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
#
# Cosine similarity: 0.96
# Line 782: แม้ว่าเราจะเคยผิดพลาด แต่เราก็เรียนรู้จากมันได้
# Line 1173: แม้ว่าเราจะล้มเหลวแต่เราก็ได้เรียนรู้จากความผิดพลาด
#
# Cosine similarity: 0.96
# Line 897: ฉันหวังว่าจะได้พบคุณอีกครั้งในอนาคตอันใกล้นี้
# Line 1215: ผมหวังว่าจะได้พบคุณอีกครั้งในโอกาสหน้า
#
# Cosine similarity: 0.96
# Line 43: ถ้าเรารักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่มากขึ้นสำหรับคนรุ่นต่อไป
# Line 95: ถ้าเราดูแลสิ่งแวดล้อม โลกของเราก็จะสวยงามและยั่งยืนสำหรับคนรุ่นหลัง
#
# Cosine similarity: 0.96
# Line 629: ฉันเชื่อว่าการให้เวลาแก่ครอบครัวเป็นสิ่งที่มีค่าที่สุด
# Line 1806: การใช้เวลาอยู่กับครอบครัวเป็นสิ่งที่มีค่าที่สุดสำหรับฉัน
#
# Cosine similarity: 0.96
# Line 822: ฉันชอบฟังเสียงคลื่นทะเลเวลาที่ไปเที่ยวชายหาด
# Line 874: ฉันชอบไปเดินเล่นริมชายหาดเพื่อฟังเสียงคลื่นและสัมผัสลมทะเล
#
# Cosine similarity: 0.96
# Line 142: เมื่อฟังเสียงคลื่นที่ซัดเข้าหาฝั่ง ฉันรู้สึกสงบและผ่อนคลาย
# Line 2003: เมื่อฉันฟังเสียงคลื่นทะเล ฉันรู้สึกสงบและผ่อนคลาย
#
# Cosine similarity: 0.96
# Line 1407: แม่มักจะสอนให้เรารู้จักออมเงิน และวางแผนการใช้จ่ายอย่างรอบคอบ
# Line 1431: แม่มักจะสอนให้เรารู้จักประหยัด และใช้ของอย่างคุ้มค่า
#
# Cosine similarity: 0.96
# Line 473: ถ้าเรามีความคิดสร้างสรรค์ เราจะสามารถแก้ไขปัญหาได้ง่ายขึ้น
# Line 1740: ถ้าเรามีความคิดสร้างสรรค์ เราจะหาวิธีแก้ปัญหาได้
#
# Cosine similarity: 0.96
# Line 43: ถ้าเรารักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่มากขึ้นสำหรับคนรุ่นต่อไป
# Line 306: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
#
# ...
#
# Cosine similarity: 0.90
# Line 53: คุณมีวิธีจัดการกับความเครียดอย่างไรบ้าง แชร์ให้ฉันฟังหน่อยได้ไหม
# Line 1312: ฉันกำลังเรียนรู้ที่จะจัดการกับความเครียดด้วยวิธีที่สร้างสรรค์
#
# Cosine similarity: 0.90
# Line 56: เธอเคยลองเล่นโยคะหรือไม่ มันช่วยให้ร่างกายและจิตใจแข็งแรงขึ้น
# Line 1314: เธอแนะนำให้ฉันลองเล่นโยคะเพื่อเพิ่มความยืดหยุ่นของร่างกาย
#
# Cosine similarity: 0.90
# Line 18: เมื่อไหร่ที่คุณมีปัญหา สามารถปรึกษาฉันได้เสมอ ฉันยินดีที่จะช่วยเหลือ
# Line 806: ถ้าเธอต้องการคำปรึกษา ฉันยินดีที่จะช่วยเหลือ
#
# Cosine similarity: 0.90
# Line 344: ถ้าคุณมีคำถาม อย่าลังเลที่จะถาม ฉันยินดีที่จะตอบ
# Line 838: ถ้าคุณมีคำถามเพิ่มเติม โปรดอย่าลังเลที่จะถาม
#
# Cosine similarity: 0.90
# Line 127: เมื่อถึงฤดูหนาว อากาศจะเย็นลงและใบไม้จะเปลี่ยนสี
# Line 1041: ฉันชอบอากาศเย็นของฤดูใบไม้ร่วงและสีสันของใบไม้ที่เปลี่ยนไป
#
# Cosine similarity: 0.90
# Line 299: ถ้าเรามีความมุ่งมั่นและอดทน เราก็จะสามารถบรรลุเป้าหมายได้
# Line 1811: เมื่อเรามีเป้าหมายเราก็ควรพยายามอย่างเต็มที่เพื่อให้บรรลุ
#
# Cosine similarity: 0.90
# Line 76: เธอมีสถานที่ท่องเที่ยวที่อยากไปบ้างไหม เราอาจวางแผนไปด้วยกันได้
# Line 1687: ถ้าเธอพร้อมแล้ว เราออกเดินทางกันเลยดีไหม
#
# Cosine similarity: 0.90
# Line 718: การวางแผนที่ดีจะช่วยให้เราสามารถจัดการเวลาและทรัพยากรได้อย่างมีประสิทธิภาพ
# Line 1986: การวางแผนล่วงหน้าจะช่วยให้เราทำงานได้อย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.90
# Line 1025: ถ้าคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
# Line 1950: ถ้าคุณมีคำถาม สามารถถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 466: ถ้าคุณพร้อม เราจะเริ่มการนำเสนอได้เลย
# Line 1166: ถ้าคุณพร้อมแล้วเราจะเริ่มประชุมกันตอนนี้เลย
#
# Cosine similarity: 0.90
# Line 272: วันนี้อากาศดีมาก แต่พรุ่งนี้อาจจะฝนตก เราควรเตรียมร่มไปด้วยนะ
# Line 1732: คุณคิดว่าฝนจะตกหรือไม่ ฉันควรพกร่มไปด้วยไหม
#
# Cosine similarity: 0.90
# Line 707: เขาชอบอ่านหนังสือวิทยาศาสตร์ เพื่อเรียนรู้เกี่ยวกับจักรวาลและธรรมชาติ
# Line 1101: ฉันชอบอ่านหนังสือเกี่ยวกับจักรวาลและดาราศาสตร์
#
# Cosine similarity: 0.90
# Line 18: เมื่อไหร่ที่คุณมีปัญหา สามารถปรึกษาฉันได้เสมอ ฉันยินดีที่จะช่วยเหลือ
# Line 1950: ถ้าคุณมีคำถาม สามารถถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 49: การฟังเพลงโปรดช่วยให้ฉันรู้สึกดีขึ้นในวันที่เหนื่อยล้า
# Line 1045: เมื่อเราฟังเพลงที่ชอบ จะช่วยให้เรารู้สึกดีขึ้น
#
# Cosine similarity: 0.90
# Line 485: การตั้งเป้าหมายที่ชัดเจนช่วยให้เราบรรลุสิ่งที่ต้องการ
# Line 922: เมื่อเรามีเป้าหมายที่ชัดเจน เราก็จะมุ่งมั่นและไม่หลงทาง
#
# Cosine similarity: 0.90
# Line 592: เราควรไปเยี่ยมชมพิพิธภัณฑ์ศิลปะ เพราะมีนิทรรศการที่น่าสนใจ
# Line 1597: ถ้าคุณมีเวลาว่าง เราไปดูนิทรรศการศิลปะกันไหม?
#
# Cosine similarity: 0.90
# Line 112: ในช่วงวันหยุดยาวนี้ ฉันอยากไปเที่ยวทะเลและพักผ่อนริมชายหาด
# Line 1927: ถ้าคุณมีเวลาว่างสุดสัปดาห์นี้ เราไปเที่ยวทะเลกันไหม
#
# Cosine similarity: 0.90
# Line 200: เมื่อเช้านี้ผมไปวิ่งที่สวน และรู้สึกสดชื่นมากขึ้น
# Line 1761: เมื่อฉันมีเวลาว่างฉันมักจะไปวิ่งที่สวนเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.90
# Line 500: ฉันเชื่อว่าการดูแลสุขภาพด้วยการออกกำลังกายและกินอาหารที่มีประโยชน์ สำคัญต่อการมีชีวิตที่ดี
# Line 1273: การกินอาหารที่มีประโยชน์เป็นสิ่งสำคัญสำหรับสุขภาพที่ดี
#
# Cosine similarity: 0.90
# Line 1203: ฉันอยากลองทำอาหารสูตรใหม่ที่พบในอินเทอร์เน็ต
# Line 1683: ฉันอยากลองทำอาหารสูตรใหม่ ที่เห็นในรายการทีวี
#
# Cosine similarity: 0.90
# Line 307: การฟังเพลงช่วยให้ฉันผ่อนคลายและสร้างสมาธิในการทำงาน
# Line 1794: การฟังเพลงโปรดช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
#
# Cosine similarity: 0.90
# Line 1118: เราไม่ควรเสียเวลาอีกต่อไป มาเริ่มงานกันเถอะ
# Line 1698: เรามีเวลาจำกัด ดังนั้นเราควรเริ่มงานทันที
#
# Cosine similarity: 0.90
# Line 550: ถ้าเรารู้จักการบริหารความเครียด เราก็จะมีชีวิตที่สมดุลและมีสุขภาพจิตที่ดี
# Line 1085: ถ้าเราดูแลสุขภาพกายและใจ ชีวิตก็จะสมดุลและมีความสุข
#
# Cosine similarity: 0.90
# Line 3: แม้ว่าฝนจะตกหนัก แต่ฉันก็ยังต้องไปทำงานเพราะมีการประชุมสำคัญที่ต้องเข้าร่วม
# Line 1342: แม้ว่าฝนจะตกหนัก แต่พวกเราก็ยังต้องออกไปทำงานตามปกติ
#
# Cosine similarity: 0.90
# Line 430: ฉันลองทำสูตรอาหารใหม่และผลลัพธ์ออกมาอร่อยมาก
# Line 786: ฉันอยากลองทำอาหารสูตรใหม่ที่เห็นในอินเตอร์เน็ต
#
# Cosine similarity: 0.90
# Line 157: ถ้าเรามีความกรุณาและเอาใจใส่ต่อผู้อื่น โลกจะน่าอยู่ขึ้น
# Line 306: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
#
# Cosine similarity: 0.90
# Line 157: ถ้าเรามีความกรุณาและเอาใจใส่ต่อผู้อื่น โลกจะน่าอยู่ขึ้น
# Line 636: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
#
# Cosine similarity: 0.90
# Line 436: ฉันอยากเรียนรู้การทำสวนเพื่อปลูกผักและผลไม้เอง
# Line 783: ฉันวางแผนจะปลูกผักสวนครัวเองที่บ้าน
#
# Cosine similarity: 0.90
# Line 578: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
# Line 1090: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.90
# Line 565: เมื่อวานนี้ฝนตกหนักมาก ทำให้ถนนลื่นและต้องขับรถอย่างระมัดระวัง
# Line 1747: ฤดูฝนปีนี้ฝนตกบ่อยมากทำให้ถนนลื่นต้องระวังเวลาเดินทาง
#
# Cosine similarity: 0.90
# Line 810: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 1963: ฉันตั้งใจว่าจะออกกำลังกายทุกวันแต่บางครั้งก็ขี้เกียจ
#
# Cosine similarity: 0.90
# Line 1596: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 1963: ฉันตั้งใจว่าจะออกกำลังกายทุกวันแต่บางครั้งก็ขี้เกียจ
#
# Cosine similarity: 0.90
# Line 50: ถ้าเรามีความตั้งใจจริง ไม่ว่าอะไรก็สามารถทำได้สำเร็จ
# Line 508: ถ้าเรามีความพยายามและไม่ยอมแพ้ เราก็จะสามารถบรรลุเป้าหมายที่ตั้งไว้ได้
#
# Cosine similarity: 0.90
# Line 430: ฉันลองทำสูตรอาหารใหม่และผลลัพธ์ออกมาอร่อยมาก
# Line 666: ฉันกำลังพยายามทำอาหารสูตรใหม่ แต่ดูเหมือนว่าจะต้องฝึกฝนอีกมาก
#
# Cosine similarity: 0.90
# Line 187: ถ้าคุณว่างวันเสาร์นี้ เราไปดูหนังเรื่องใหม่ด้วยกันดีไหม?
# Line 1796: คุณอยากไปดูหนังเรื่องใหม่ที่เข้าฉายสุดสัปดาห์นี้กับฉันไหม
#
# Cosine similarity: 0.90
# Line 28: ในช่วงวันหยุดยาวนี้ เราวางแผนจะไปเที่ยวต่างจังหวัดกับครอบครัว
# Line 1094: ฉันวางแผนจะเดินทางไปเยี่ยมเพื่อนที่ต่างจังหวัดในวันหยุดนี้
#
# Cosine similarity: 0.90
# Line 1325: การรับฟังความคิดเห็นของผู้อื่นช่วยให้เรามีมุมมองที่กว้างขึ้น
# Line 1331: การเปิดใจรับฟังความคิดเห็นที่แตกต่างจะช่วยให้เราเติบโตขึ้น
#
# Cosine similarity: 0.90
# Line 508: ถ้าเรามีความพยายามและไม่ยอมแพ้ เราก็จะสามารถบรรลุเป้าหมายที่ตั้งไว้ได้
# Line 1017: ถึงแม้ว่ามันจะยาก แต่ถ้าเราพยายาม เราก็จะประสบความสำเร็จได้
#
# Cosine similarity: 0.90
# Line 212: คุณคิดว่าวันหยุดนี้เราควรไปเที่ยวภูเขาหรือทะเลดี?
# Line 608: ถ้าคุณต้องการพักผ่อน เราสามารถไปเที่ยวทะเลหรือภูเขาก็ได้
#
# Cosine similarity: 0.90
# Line 773: ฉันเพิ่งเรียนรู้วิธีการทำขนมเค้กสูตรใหม่ที่อร่อยมาก
# Line 1265: เธอสามารถสอนฉันทำขนมเค้กสูตรนี้ได้ไหม มันดูน่าอร่อยมาก
#
# Cosine similarity: 0.90
# Line 814: ถึงแม้ว่าฝนจะตกหนัก แต่เราก็ยังไปเที่ยวได้
# Line 1700: แม้ว่าสภาพอากาศจะไม่ดี แต่เรายังคงเดินทางต่อไปได้
#
# Cosine similarity: 0.90
# Line 627: ถ้าเรามีความมุ่งมั่นและความพยายาม เราจะสามารถทำได้ทุกอย่าง
# Line 1649: แม้ว่างานจะยาก แต่ถ้าเราพยายาม เราจะสำเร็จได้
#
# Cosine similarity: 0.90
# Line 1215: ผมหวังว่าจะได้พบคุณอีกครั้งในโอกาสหน้า
# Line 1731: ฉันดีใจที่ได้พบคุณอีกครั้ง หลังจากเวลาผ่านไปนาน
#
# Cosine similarity: 0.90
# Line 1541: หลังจากที่ฝนหยุดตก เราควรออกไปซื้อของที่ตลาดไหม?
# Line 1759: ถึงแม้ว่าฝนจะตกเราก็ยังสามารถไปช็อปปิ้งที่ห้างสรรพสินค้าได้
#
# Cosine similarity: 0.90
# Line 126: ความสุขไม่ได้อยู่ที่ว่าเรามีอะไร แต่อยู่ที่ว่าเรารู้สึกอย่างไรกับสิ่งที่มี
# Line 1988: ความสุขไม่ใช่สิ่งที่หาได้จากภายนอก แต่เป็นสิ่งที่อยู่ภายในใจเรา
#
# Cosine similarity: 0.90
# Line 207: ถ้าคุณต้องการความช่วยเหลือ ผมยินดีที่จะช่วยเสมอ
# Line 602: ฉันรู้สึกขอบคุณสำหรับการสนับสนุนและความช่วยเหลือจากคุณเสมอมา
#
# Cosine similarity: 0.90
# Line 491: แม้ว่าวันนี้อากาศจะร้อนมาก แต่ฉันก็ยังออกไปวิ่งออกกำลังกายตามปกติเพื่อสุขภาพที่ดี
# Line 858: แม้ว่าอากาศจะร้อน แต่เขาก็ยังคงวิ่งออกกำลังกายทุกเช้า
#
# Cosine similarity: 0.90
# Line 967: ในที่สุดฉันก็ได้ลองทำเค้กช็อกโกแลตสูตรของคุณยายที่เก็บไว้นาน
# Line 995: คุณแม่สอนทำเค้กช็อกโกแลตสูตรโบราณของครอบครัว
#
# Cosine similarity: 0.90
# Line 454: ฉันพบว่าโยคะช่วยให้ฉันมีสมาธิและผ่อนคลาย
# Line 626: ฉันพบว่าการนั่งสมาธิช่วยให้จิตใจสงบและมีสมาธิมากขึ้น
#
# Cosine similarity: 0.90
# Line 955: ถ้าคุณว่างเย็นนี้ เรามาดูหนังด้วยกันเถอะ มีหนังใหม่น่าสนใจหลายเรื่อง
# Line 1111: หากคุณมีเวลาว่างเราน่าจะไปดูหนังด้วยกัน
#
# Cosine similarity: 0.90
# Line 1061: เมื่อเราเปิดใจรับฟังความคิดเห็นของผู้อื่น เราจะเรียนรู้มากขึ้น
# Line 1331: การเปิดใจรับฟังความคิดเห็นที่แตกต่างจะช่วยให้เราเติบโตขึ้น
#
# Cosine similarity: 0.90
# Line 527: ถ้าเราตั้งเป้าหมายและมุ่งมั่นทำงานหนัก เราก็จะสามารถประสบความสำเร็จได้ตามที่หวัง
# Line 1649: แม้ว่างานจะยาก แต่ถ้าเราพยายาม เราจะสำเร็จได้
#
# Cosine similarity: 0.90
# Line 66: การอ่านหนังสือหลากหลายแนวช่วยเปิดโลกทัศน์และความคิดสร้างสรรค์
# Line 305: การอ่านหนังสือทำให้เราเปิดใจกว้างและเข้าใจโลกมากขึ้น
#
# Cosine similarity: 0.90
# Line 1281: คุณต้องการให้ฉันช่วยอะไรไหม ฉันยินดีที่จะช่วยเต็มที่
# Line 1634: คุณต้องการให้ฉันช่วยอะไรเพิ่มเติมหรือไม่?
#
# Cosine similarity: 0.90
# Line 148: ฉันชอบดื่มชาร้อนกับขนมปังปิ้งในตอนเช้า
# Line 470: ฉันชอบดื่มชาเขียวร้อนในตอนเช้าเพื่อเริ่มต้นวันใหม่
#
# Cosine similarity: 0.90
# Line 38: ฉันรู้สึกซาบซึ้งในความมีน้ำใจของคุณ ที่คอยช่วยเหลือฉันเสมอมา
# Line 1309: ฉันอยากขอบคุณคุณสำหรับความช่วยเหลือและการสนับสนุนที่ต่อเนื่อง
#
# Cosine similarity: 0.90
# Line 1550: การออกกำลังกายเป็นประจำช่วยให้สุขภาพดีขึ้น คุณคิดอย่างไร?
# Line 1750: การออกกำลังกายทุกวันช่วยให้สุขภาพแข็งแรงและจิตใจแจ่มใส
#
# Cosine similarity: 0.90
# Line 13: ถ้าเราต้องการประสบความสำเร็จ เราควรตั้งเป้าหมายและพยายามอย่างเต็มที่เพื่อให้ไปถึง
# Line 86: ถ้าเรามีเป้าหมายที่ชัดเจน เราก็จะมุ่งมั่นและพยายามได้ง่ายขึ้น
#
# Cosine similarity: 0.90
# Line 533: ถ้าเรามองโลกในแง่ดี ชีวิตของเราก็จะเต็มไปด้วยพลังและความหวัง
# Line 1080: เมื่อเรามีทัศนคติที่ดี ชีวิตก็จะมีความสุขมากขึ้น
#
# Cosine similarity: 0.90
# Line 601: ถ้าคุณไม่สะดวกที่จะพบกันวันนี้ เราสามารถนัดใหม่วันอื่นได้
# Line 1247: ถ้าวันนี้คุณยุ่ง เราสามารถเลื่อนการประชุมไปเป็นวันพรุ่งนี้ได้
#
# Cosine similarity: 0.90
# Line 315: การทำงานเป็นทีมจะทำให้เราสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 431: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.90
# Line 315: การทำงานเป็นทีมจะทำให้เราสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 1602: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.90
# Line 827: ฉันชอบปลูกต้นไม้และดูแลสวนในเวลาว่าง
# Line 1082: ฉันชอบปลูกต้นไม้และดอกไม้ในสวน เพราะทำให้บ้านสวยงาม
#
# Cosine similarity: 0.90
# Line 159: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 782: แม้ว่าเราจะเคยผิดพลาด แต่เราก็เรียนรู้จากมันได้
#
# Cosine similarity: 0.90
# Line 728: ฉันหวังว่าคุณจะสนุกกับการเดินทางครั้งนี้และเก็บประสบการณ์ที่ดี
# Line 1765: การเดินทางครั้งนี้จะเป็นประสบการณ์ที่ดีสำหรับพวกเราทุกคน
#
# Cosine similarity: 0.90
# Line 747: ถ้าคุณมีคำถามเกี่ยวกับงาน โปรดติดต่อฉันได้ตลอดเวลา
# Line 1950: ถ้าคุณมีคำถาม สามารถถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 589: ถ้าคุณต้องการความช่วยเหลือในการทำงาน โปรดบอกฉันได้เลย
# Line 853: ถ้าเธอต้องการความช่วยเหลือ โปรดอย่าลังเลที่จะบอกฉัน
#
# Cosine similarity: 0.90
# Line 278: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกภูมิใจที่ได้ทำงานสำเร็จตามเป้าหมาย
# Line 1135: แม้ว่าวันนี้จะยุ่งแต่ฉันก็มีความสุขที่ได้ช่วยเหลือคนอื่น
#
# Cosine similarity: 0.90
# Line 239: ผมพบร้านอาหารใหม่ที่อาหารอร่อยมาก คุณต้องลองไป
# Line 1229: คุณควรลองร้านอาหารใหม่ที่เปิดตรงมุมถนน อาหารอร่อยมาก
#
# Cosine similarity: 0.90
# Line 559: ฉันชอบการฟังเสียงฝนตก เพราะมันทำให้ฉันรู้สึกสงบและผ่อนคลาย
# Line 769: ฉันชอบฟังเสียงฝนตกเวลาที่นอนพักผ่อนอยู่บ้าน
#
# Cosine similarity: 0.90
# Line 141: ฉันตั้งใจว่าจะเรียนภาษาใหม่เพื่อเปิดโอกาสในการทำงานมากขึ้น
# Line 1574: ฉันคิดว่าการเรียนรู้ภาษาใหม่เป็นการเปิดโอกาสให้กับชีวิต
#
# Cosine similarity: 0.90
# Line 289: วันนี้ฉันตื่นเช้าเพื่อไปวิ่งออกกำลังกาย และรู้สึกสดชื่นมากตลอดวัน
# Line 1474: หลังจากออกกำลังกาย ฉันรู้สึกสดชื่นขึ้นมาก
#
# Cosine similarity: 0.90
# Line 7: เธอช่วยอธิบายวิธีการใช้โปรแกรมนี้ให้ฉันฟังอีกครั้งได้ไหม ฉันยังไม่ค่อยเข้าใจ
# Line 1764: คุณช่วยอธิบายปัญหานี้ให้ฉันฟังอีกครั้งได้ไหมฉันยังไม่เข้าใจ
#
# Cosine similarity: 0.90
# Line 404: ฉันกำลังหัดเล่นกีตาร์ แต่ยังไม่เก่งเท่าไหร่
# Line 1613: ฉันเพิ่งเริ่มเรียนเล่นกีตาร์ และมันท้าทายมากแต่สนุก
#
# Cosine similarity: 0.90
# Line 542: ฉันสนใจในการศึกษาประวัติศาสตร์ เพื่อเข้าใจถึงรากฐานและความเป็นมาของสังคม
# Line 1726: ฉันสนใจเรียนรู้เกี่ยวกับวัฒนธรรมและประวัติศาสตร์
#
# Cosine similarity: 0.90
# Line 77: การออกไปเดินชมธรรมชาติช่วยให้จิตใจสงบและลดความเครียด
# Line 613: เมื่อฉันรู้สึกเครียด ฉันมักจะออกไปเดินเล่นเพื่อผ่อนคลายจิตใจ
#
# Cosine similarity: 0.90
# Line 500: ฉันเชื่อว่าการดูแลสุขภาพด้วยการออกกำลังกายและกินอาหารที่มีประโยชน์ สำคัญต่อการมีชีวิตที่ดี
# Line 650: การออกกำลังกายเป็นประจำเป็นสิ่งสำคัญสำหรับสุขภาพที่ดีและชีวิตที่ยืนยาว
#
# Cosine similarity: 0.90
# Line 578: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
# Line 1754: ฉันชอบฟังเพลงคลาสสิกเวลาทำงานเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 0.90
# Line 308: แม้ว่าเส้นทางจะยากลำบาก แต่ฉันก็จะไม่ยอมแพ้และจะเดินหน้าต่อไป
# Line 330: แม้ว่าฉันจะผิดหวัง แต่ฉันก็จะไม่ยอมแพ้และจะพยายามต่อไป
#
# Cosine similarity: 0.90
# Line 17: ถึงแม้ว่าเราจะพบกับอุปสรรคมากมาย แต่ก็ไม่ควรยอมแพ้และควรสู้ต่อไป
# Line 849: แม้ว่าจะมีอุปสรรคมากมาย เรายังคงมุ่งมั่นที่จะประสบความสำเร็จ
#
# Cosine similarity: 0.90
# Line 173: ฉันชอบชมพระจันทร์เต็มดวงที่ส่องแสงสว่างบนท้องฟ้ายามค่ำคืน
# Line 1063: ฉันสนใจเรื่องดาราศาสตร์และชอบดูดาวในคืนที่ท้องฟ้าแจ่มใส
#
# Cosine similarity: 0.90
# Line 344: ถ้าคุณมีคำถาม อย่าลังเลที่จะถาม ฉันยินดีที่จะตอบ
# Line 1607: ถ้าคุณมีข้อสงสัย โปรดอย่าลังเลที่จะถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 699: เมื่อฤดูหนาวมาเยือน อากาศก็เย็นลงและใบไม้ก็เริ่มเปลี่ยนสี
# Line 1041: ฉันชอบอากาศเย็นของฤดูใบไม้ร่วงและสีสันของใบไม้ที่เปลี่ยนไป
#
# Cosine similarity: 0.90
# Line 19: ฉันอยากเรียนรู้ภาษาใหม่ เพราะจะได้สื่อสารกับคนต่างชาติได้ดีขึ้น
# Line 141: ฉันตั้งใจว่าจะเรียนภาษาใหม่เพื่อเปิดโอกาสในการทำงานมากขึ้น
#
# Cosine similarity: 0.90
# Line 716: ถ้าคุณรู้สึกไม่สบายใจ โปรดบอกฉัน ฉันพร้อมที่จะช่วยเหลือ
# Line 774: ถ้าคุณต้องการความช่วยเหลือ โปรดบอกฉันได้เลย
#
# Cosine similarity: 0.90
# Line 492: การเรียนภาษาใหม่ไม่ใช่เรื่องง่าย แต่ถ้าเราฝึกฝนอย่างสม่ำเสมอ เราก็จะเก่งขึ้นได้
# Line 1027: การเรียนรู้ภาษาใหม่ต้องใช้เวลาและความพยายามอย่างมาก
#
# Cosine similarity: 0.90
# Line 233: ฉันอยากลองทำขนมไทยแบบดั้งเดิม แต่ต้องหาสูตรก่อน
# Line 1716: ฉันเพิ่งเรียนรู้สูตรขนมใหม่ และอยากลองทำดู
#
# Cosine similarity: 0.90
# Line 1185: เธอกำลังเรียนรู้ที่จะเล่นกีตาร์และทำได้ดีมาก
# Line 1259: เธอกำลังฝึกเล่นกีตาร์เพื่อแสดงในงานคอนเสิร์ตของโรงเรียน
#
# Cosine similarity: 0.90
# Line 998: มาเที่ยวสวนสาธารณะกันเถอะ อากาศดีมาก
# Line 1158: ถ้าอากาศดีเราควรจัดปิกนิกที่สวนสาธารณะ
#
# Cosine similarity: 0.90
# Line 604: เธออยากไปเรียนโยคะกับฉันไหม มันช่วยผ่อนคลายและดีต่อสุขภาพ
# Line 1285: ฉันอยากลองฝึกโยคะเพื่อเสริมสร้างสุขภาพกายและจิตใจ
#
# Cosine similarity: 0.90
# Line 107: ถ้าคุณมีเวลาว่างพรุ่งนี้ เราไปดูหนังเรื่องใหม่ที่เพิ่งเข้าฉายกันเถอะ
# Line 187: ถ้าคุณว่างวันเสาร์นี้ เราไปดูหนังเรื่องใหม่ด้วยกันดีไหม?
#
# Cosine similarity: 0.90
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 1628: ฉันตั้งตารอคอยวันที่เราจะได้ทำงานร่วมกันอีกครั้ง
#
# Cosine similarity: 0.90
# Line 861: ถ้าเราเริ่มต้นตั้งแต่ตอนนี้ เราจะมีเวลามากพอที่จะทำงานเสร็จ
# Line 1118: เราไม่ควรเสียเวลาอีกต่อไป มาเริ่มงานกันเถอะ
#
# Cosine similarity: 0.90
# Line 24: ฉันกำลังคิดจะซื้อต้นไม้มาปลูกในบ้าน เพื่อเพิ่มความสดชื่นและความสวยงาม
# Line 1082: ฉันชอบปลูกต้นไม้และดอกไม้ในสวน เพราะทำให้บ้านสวยงาม
#
# Cosine similarity: 0.90
# Line 737: ถ้าเธอว่างพรุ่งนี้ เราไปเดินเล่นที่สวนสาธารณะกันไหม
# Line 890: ถ้าอากาศดี พรุ่งนี้เราจะไปปิกนิกที่สวนสาธารณะกันไหม
#
# Cosine similarity: 0.90
# Line 68: แม้ว่าจะเป็นเรื่องยาก แต่ถ้าเราพยายามอย่างเต็มที่ ก็ไม่มีอะไรที่เป็นไปไม่ได้
# Line 974: งานนี้ยากกว่าที่คิดไว้มาก แต่เราต้องพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.90
# Line 701: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 912: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้เพื่อเป้าหมายที่ยิ่งใหญ่กว่า
#
# Cosine similarity: 0.90
# Line 431: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 551: การร่วมมือกันในทีมทำให้เราสามารถบรรลุเป้าหมายที่ใหญ่ขึ้นได้เร็วกว่า
#
# Cosine similarity: 0.90
# Line 551: การร่วมมือกันในทีมทำให้เราสามารถบรรลุเป้าหมายที่ใหญ่ขึ้นได้เร็วกว่า
# Line 1602: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.90
# Line 438: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 1490: เมื่อฉันเครียด ฉันชอบฟังเพลงเพื่อผ่อนคลาย
#
# Cosine similarity: 0.90
# Line 1388: คุณครูวิทยาศาสตร์สอนให้เรารู้จักสังเกตธรรมชาติ และทำการทดลองอย่างปลอดภัย
# Line 1411: คุณครูวิทยาศาสตร์สอนให้เรารักษาสิ่งแวดล้อม และทำโครงงานเกี่ยวกับการรีไซเคิล
#
# Cosine similarity: 0.90
# Line 378: แม้ว่าจะมีอุปสรรค แต่ฉันเชื่อว่าเราจะร่วมมือกันผ่านมันไปได้
# Line 1458: ถึงแม้ว่าจะมีปัญหา แต่เราก็สามารถแก้ไขได้ด้วยกัน
