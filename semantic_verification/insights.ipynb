# %% [markdown]
# # Import Libraries

# %%
from tqdm import tqdm
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data

# %%
import pickle

with open("pickled/cosine_similarities.pkl", "rb") as f:
    cosine_similarities = pickle.load(f)
with open("pickled/embeddings_bge-m3.pkl", "rb") as f:
    np_encoded_texts = pickle.load(f)

# %%
generated_path = "../generated/processed/combined_sentences_with_phoneme.csv"
df = pd.read_csv(generated_path)

# %% [markdown]
# # Binning

# %%
sorted_cosine_similarities = sorted(cosine_similarities.items(), key=lambda x: x[1], reverse=True)

# do binning
bins = np.linspace(0, 1, 11)
bin_counts = np.zeros(10, dtype=int)
for _, cosine_sim in tqdm(sorted_cosine_similarities):
    for i in range(10):
        if cosine_sim < bins[i + 1]:
            bin_counts[i] += 1
            break
# Out:
# 100%|██████████| 3136260/3136260 [00:07<00:00, 403209.44it/s]

# %%
print(bin_counts)
# Out:
# [      0       0       0       0      14  154985 2395173  556237   27624
#     2217]

# %%
with open("results/bin_result.txt", "w") as f:
    for i, count in enumerate(bin_counts):
        f.write(f"Bin {i}: {count}\n")

# %% [markdown]
# # Thresholding

# %%
threshold = 0.9
cos_sims, line1, sent1, line2, sent2 = [], [], [], [], []
for (i, j), cosine_sim in sorted_cosine_similarities:
    if cosine_sim < threshold:
        break
    print(f"Cosine similarity: {cosine_sim:.2f}")
    print(f"Line {i+2}: {df.iloc[i]['thai sentence']}")
    print(f"Line {j+2}: {df.iloc[j]['thai sentence']}")
    print()
    cos_sims.append(round(cosine_sim, 3))
    line1.append(i+2)
    line2.append(j+2)
    sent1.append(df.iloc[i]['thai sentence'])
    sent2.append(df.iloc[j]['thai sentence'])
df_sim = pd.DataFrame({"cosine similarity": cos_sims, "line1": line1, "sentence1": sent1, "line2": line2, "sentence2": sent2})
df_sim.to_csv("results/cosine_similarities.csv", index=False)
# Out:
# Cosine similarity: 1.00
# Line 721: ถ้าเราไม่ลอง เราก็จะไม่รู้ว่าผลลัพธ์จะเป็นอย่างไร
# Line 1244: ถ้าเราไม่ลอง เราก็จะไม่รู้ว่าผลลัพธ์จะเป็นอย่างไร
#
# Cosine similarity: 1.00
# Line 1183: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 1969: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 1.00
# Line 1223: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1391: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 567: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
# Line 1009: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
#
# Cosine similarity: 1.00
# Line 692: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 1975: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 1.00
# Line 1082: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
# Line 1660: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 1.00
# Line 1205: คุณคิดว่าอนาคตของเทคโนโลยีจะเป็นอย่างไร
# Line 2506: คุณคิดว่าอนาคตของเทคโนโลยีจะเป็นอย่างไร
#
# Cosine similarity: 1.00
# Line 1526: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 2082: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1526: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 2457: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 2082: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 2457: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 2114: ฉันหวังว่าเราจะมีโอกาสได้ทำงานร่วมกันอีกในอนาคต
#
# Cosine similarity: 1.00
# Line 1242: ฉันกำลังมองหาของขวัญที่พิเศษสำหรับวันเกิดของแม่
# Line 2039: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 1.00
# Line 937: ถ้าคุณมีเวลาว่างสุดสัปดาห์นี้ เราไปเดินเล่นที่สวนสาธารณะกันไหม
# Line 1590: ถ้าคุณมีเวลาว่างในสุดสัปดาห์นี้ เราไปเดินเล่นที่สวนสาธารณะกันไหม
#
# Cosine similarity: 1.00
# Line 310: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 620: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
#
# Cosine similarity: 1.00
# Line 1223: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1927: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 1391: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1927: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 490: คุณสนใจที่จะเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
# Line 745: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
#
# Cosine similarity: 1.00
# Line 681: เมื่อวานนี้ฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานาน
# Line 1137: เมื่อวานฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานานมาก
#
# Cosine similarity: 1.00
# Line 681: เมื่อวานนี้ฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานาน
# Line 2249: เมื่อวานนี้ฉันพบเพื่อนเก่าที่ไม่ได้เจอกันมานานมากแล้ว
#
# Cosine similarity: 1.00
# Line 1526: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 1956: ฉันรู้สึกตื่นเต้นมากที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1956: ฉันรู้สึกตื่นเต้นมากที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 2082: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1956: ฉันรู้สึกตื่นเต้นมากที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
# Line 2457: ฉันรู้สึกตื่นเต้นที่จะได้เริ่มงานใหม่ในสัปดาห์หน้า
#
# Cosine similarity: 1.00
# Line 1137: เมื่อวานฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานานมาก
# Line 2249: เมื่อวานนี้ฉันพบเพื่อนเก่าที่ไม่ได้เจอกันมานานมากแล้ว
#
# Cosine similarity: 1.00
# Line 660: ฉันเคยไปญี่ปุ่นเมื่อปีที่แล้วและประทับใจในวัฒนธรรมของเขา
# Line 2228: ฉันเคยไปญี่ปุ่นเมื่อปีที่แล้วและประทับใจในวัฒนธรรมของเขามาก
#
# Cosine similarity: 1.00
# Line 1480: เมื่อวานนี้ฉันได้พบเพื่อนเก่าที่ไม่ได้เจอกันนานมาก
# Line 2249: เมื่อวานนี้ฉันพบเพื่อนเก่าที่ไม่ได้เจอกันมานานมากแล้ว
#
# Cosine similarity: 1.00
# Line 266: การออกกำลังกายเป็นประจำช่วยให้สุขภาพแข็งแรงและจิตใจสดใส
# Line 557: การออกกำลังกายเป็นประจำจะช่วยให้สุขภาพแข็งแรงและจิตใจสดใส
#
# Cosine similarity: 1.00
# Line 957: ถ้าเราออกเดินทางตอนนี้ เราจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
# Line 1387: ถ้าเราออกเดินทางตอนนี้ เราจะไปถึงจุดหมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 1.00
# Line 1058: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 1.00
# Line 665: ฉันกำลังหัดเล่นกีตาร์ แต่ยังไม่เก่งเท่าไหร่
# Line 2030: ฉันกำลังหัดเล่นกีตาร์ แต่ยังไม่ค่อยเก่งเท่าไหร่
#
# Cosine similarity: 1.00
# Line 42: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญ ที่จะทำให้เราเติบโตและพัฒนา
# Line 907: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญที่ช่วยให้เราเติบโตและพัฒนา
#
# Cosine similarity: 1.00
# Line 1053: เราควรรักษาสิ่งแวดล้อม เพื่ออนาคตของลูกหลานของเรา
# Line 1180: เราควรจะรักษาสิ่งแวดล้อมเพื่ออนาคตของลูกหลาน
#
# Cosine similarity: 1.00
# Line 1138: ฉันอยากเรียนรู้วิธีการถ่ายภาพให้สวยงามมากขึ้น
# Line 1974: ฉันอยากเรียนรู้วิธีการถ่ายภาพให้สวยงามกว่าเดิม
#
# Cosine similarity: 1.00
# Line 1257: เขากำลังวางแผนที่จะเรียนต่อในระดับปริญญาโทที่ต่างประเทศ
# Line 1528: เขากำลังวางแผนที่จะเรียนต่อปริญญาโทในต่างประเทศ
#
# Cosine similarity: 1.00
# Line 681: เมื่อวานนี้ฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานาน
# Line 1480: เมื่อวานนี้ฉันได้พบเพื่อนเก่าที่ไม่ได้เจอกันนานมาก
#
# Cosine similarity: 1.00
# Line 1137: เมื่อวานฉันเจอเพื่อนเก่าที่ไม่ได้พบกันมานานมาก
# Line 1480: เมื่อวานนี้ฉันได้พบเพื่อนเก่าที่ไม่ได้เจอกันนานมาก
#
# Cosine similarity: 1.00
# Line 711: ถ้าอากาศดีสุดสัปดาห์นี้ เราไปปิกนิกกันไหม?
# Line 2045: ถ้าอากาศดีสุดสัปดาห์นี้ เราไปปิกนิกกันไหม
#
# Cosine similarity: 1.00
# Line 1503: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
# Line 1927: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 945: ฉันต้องการซื้อของขวัญให้แม่ แต่ยังไม่แน่ใจว่าจะเลือกอะไรดี
# Line 1131: ฉันต้องการซื้อของขวัญให้แม่แต่ยังไม่รู้จะเลือกอะไรดี
#
# Cosine similarity: 1.00
# Line 538: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 936: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
#
# Cosine similarity: 1.00
# Line 32: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีอะไรแนะนำไหม
# Line 1606: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีคำแนะนำไหม
#
# Cosine similarity: 1.00
# Line 1077: เราควรเคารพความคิดเห็นของผู้อื่น แม้ว่าเราจะไม่เห็นด้วยก็ตาม
# Line 2472: เราควรเคารพความคิดเห็นของผู้อื่นแม้ว่าเราจะไม่เห็นด้วย
#
# Cosine similarity: 1.00
# Line 78: ถ้าเรารู้จักการจัดลำดับความสำคัญ เราก็จะบริหารเวลาได้อย่างมีประสิทธิภาพ
# Line 933: ถ้าเรารู้จักการจัดลำดับความสำคัญ เราก็จะสามารถบริหารเวลาได้อย่างมีประสิทธิภาพ
#
# Cosine similarity: 1.00
# Line 1812: เมื่อวานนี้ฉันไปหาหมอฟัน เพราะปวดฟันมาหลายวันแล้ว
# Line 2343: เมื่อวานนี้ฉันจึงไปพบหมอฟันเพราะปวดฟันมาหลายวันแล้ว
#
# Cosine similarity: 1.00
# Line 303: การอ่านข่าวทุกวันทำให้เราทันเหตุการณ์และรอบรู้มากขึ้น
# Line 607: การอ่านข่าวทุกวันจะช่วยให้เราทันเหตุการณ์และรอบรู้มากขึ้น
#
# Cosine similarity: 1.00
# Line 310: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1291: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
#
# Cosine similarity: 1.00
# Line 548: ฉันชอบฟังเพลงเวลาขับรถ เพราะทำให้การเดินทางสนุกสนานขึ้น
# Line 2037: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางสนุกขึ้น
#
# Cosine similarity: 1.00
# Line 1223: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1503: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 1391: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
# Line 1503: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 1.00
# Line 745: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
# Line 2482: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือเปล่า
#
# Cosine similarity: 1.00
# Line 1965: ฉันหวังว่าอากาศจะดีในวันหยุด เพื่อที่เราจะได้ไปปิกนิก
# Line 2303: ฉันหวังว่าอากาศจะดีในวันหยุดนี้เพื่อที่เราจะได้ไปปิกนิกกัน
#
# Cosine similarity: 1.00
# Line 1992: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้อีกในอนาคต
# Line 2114: ฉันหวังว่าเราจะมีโอกาสได้ทำงานร่วมกันอีกในอนาคต
#
# Cosine similarity: 1.00
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 1992: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้อีกในอนาคต
#
# Cosine similarity: 1.00
# Line 738: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจในชุมชน
# Line 1701: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อช่วยเศรษฐกิจของชุมชน
#
# Cosine similarity: 1.00
# Line 10: หากเราวางแผนการเดินทางล่วงหน้า เราจะสามารถประหยัดค่าใช้จ่ายและเวลาได้มากขึ้น
# Line 1021: หากเราวางแผนการเดินทางล่วงหน้า เราจะสามารถประหยัดทั้งเวลาและเงินได้มากขึ้น
#
# Cosine similarity: 0.99
# Line 620: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1291: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
#
# Cosine similarity: 0.99
# Line 1500: ฉันต้องการซื้อของขวัญให้เพื่อนแต่ยังไม่รู้ว่าจะซื้ออะไรดี
# Line 2093: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่รู้ว่าจะเลือกอะไรดี
#
# Cosine similarity: 0.99
# Line 490: คุณสนใจที่จะเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือไม่?
# Line 2482: คุณสนใจเข้าร่วมกิจกรรมอาสาสมัครกับเราหรือเปล่า
#
# Cosine similarity: 0.99
# Line 2283: ฉันรู้สึกขอบคุณสำหรับทุกสิ่งที่ฉันมีในชีวิต
# Line 2501: ฉันรู้สึกขอบคุณสำหรับทุกสิ่งที่มีในชีวิต
#
# Cosine similarity: 0.99
# Line 70: ฉันชอบเดินทางด้วยรถไฟ เพราะได้เห็นวิวทิวทัศน์สวยงามระหว่างทาง
# Line 1423: ฉันชอบเดินทางด้วยรถไฟ เพราะได้ชมวิวทิวทัศน์สวยงาม
#
# Cosine similarity: 0.99
# Line 1715: แม้ว่าฝนจะตกหนัก แต่พวกเราก็ยังต้องออกไปทำงานตามปกติ
# Line 1808: แม้ว่าฝนจะตกหนัก แต่พวกเราก็ต้องไปทำงานตามปกติ
#
# Cosine similarity: 0.99
# Line 2141: คุณพ่อชอบฟังเพลงแจ๊สแบบโบราณขณะทำงานไม้ในโรงรถช่วงสุดสัปดาห์
# Line 2156: คุณพ่อชอบทำงานไม้ไปฟังเพลงแจ๊สโบราณในโรงรถช่วงวันหยุดสุดสัปดาห์
#
# Cosine similarity: 0.99
# Line 1159: ฉันอยากลองทำอาหารสูตรใหม่ที่เห็นในอินเตอร์เน็ต
# Line 1576: ฉันอยากลองทำอาหารสูตรใหม่ที่พบในอินเทอร์เน็ต
#
# Cosine similarity: 0.99
# Line 2226: ตอนนี้ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำให้ครอบครัวทาน
# Line 2409: ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำอาหารให้ครอบครัวทาน
#
# Cosine similarity: 0.99
# Line 701: คุณสามารถแนะนำสถานที่ท่องเที่ยวที่น่าสนใจในเมืองนี้ได้ไหม?
# Line 1557: คุณสามารถแนะนำสถานที่ท่องเที่ยวที่น่าสนใจในเมืองนี้ได้ไหม
#
# Cosine similarity: 0.99
# Line 1554: ถ้าเราประหยัดเงินเราก็สามารถไปเที่ยวต่างประเทศได้
# Line 1951: ถ้าเราประหยัดเงินได้มากพอ เราสามารถไปเที่ยวต่างประเทศได้
#
# Cosine similarity: 0.99
# Line 2384: วันนี้อากาศร้อนมาก แต่ลมก็พัดโผนมาให้รู้สึกเย็นขึ้น
# Line 2394: วันนี้อากาศร้อนมาก แต่ลมก็พัดมาให้รู้สึกเย็นขึ้นหน่อย
#
# Cosine similarity: 0.99
# Line 903: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
# Line 1099: การฟังเพลงคลาสสิกช่วยให้ฉันสงบและมีสมาธิในการทำงาน
#
# Cosine similarity: 0.99
# Line 1025: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
# Line 1639: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.99
# Line 1653: การวางแผนล่วงหน้าช่วยให้เราจัดการเวลาได้มีประสิทธิภาพมากขึ้น
# Line 1957: การวางแผนล่วงหน้าช่วยให้เราจัดการเวลาได้ดีขึ้น
#
# Cosine similarity: 0.99
# Line 1082: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
# Line 1413: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีม
#
# Cosine similarity: 0.99
# Line 1413: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีม
# Line 1660: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.99
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 1703: ฉันหวังว่าเราจะมีโอกาสได้ร่วมงานกันอีกในอนาคต
#
# Cosine similarity: 0.99
# Line 1703: ฉันหวังว่าเราจะมีโอกาสได้ร่วมงานกันอีกในอนาคต
# Line 2114: ฉันหวังว่าเราจะมีโอกาสได้ทำงานร่วมกันอีกในอนาคต
#
# Cosine similarity: 0.99
# Line 2055: เราควรปลูกต้นไม้เพิ่ม เพื่อทำให้สิ่งแวดล้อมดีขึ้น
# Line 2427: เราควรปลูกต้นไม้มากขึ้นเพื่อสิ่งแวดล้อมที่ดี
#
# Cosine similarity: 0.99
# Line 33: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
# Line 563: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็รู้สึกดีที่ได้ช่วยเหลือผู้อื่น
#
# Cosine similarity: 0.99
# Line 1092: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นอยู่เสมอ
# Line 1555: เขาเป็นคนที่ใจดีและมักจะช่วยเหลือผู้อื่นเสมอ
#
# Cosine similarity: 0.99
# Line 1409: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.99
# Line 780: ฉันชอบฟังเพลงเวลาทำงานเพราะช่วยให้มีสมาธิ
# Line 1592: ฉันชอบฟังเพลงขณะทำงานเพราะมันช่วยให้ฉันมีสมาธิมากขึ้น
#
# Cosine similarity: 0.99
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
# Line 2270: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.99
# Line 1058: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 1409: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
#
# Cosine similarity: 0.99
# Line 1099: การฟังเพลงคลาสสิกช่วยให้ฉันสงบและมีสมาธิในการทำงาน
# Line 1463: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.99
# Line 1092: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นอยู่เสมอ
# Line 1233: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นเสมอเมื่อมีโอกาส
#
# Cosine similarity: 0.99
# Line 932: ฉันชอบการฟังเสียงฝนตก เพราะมันทำให้ฉันรู้สึกสงบและผ่อนคลาย
# Line 2076: ฉันชอบฟังเสียงฝนตก มันทำให้ฉันรู้สึกสงบ
#
# Cosine similarity: 0.99
# Line 1509: เราควรออกกำลังกายเป็นประจำเพื่อสุขภาพที่ดี
# Line 2416: เราควรออกกำลังกายเป็นประจำเพื่อสุขภาพที่แข็งแรง
#
# Cosine similarity: 0.99
# Line 278: เมื่อถึงฤดูหนาว อากาศจะเย็นลงและใบไม้จะเปลี่ยนสี
# Line 1072: เมื่อฤดูหนาวมาเยือน อากาศก็เย็นลงและใบไม้ก็เริ่มเปลี่ยนสี
#
# Cosine similarity: 0.99
# Line 936: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
# Line 2016: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 1489: แมวของฉันชอบนอนริมหน้าต่างที่มีแสงแดดส่องถึง
# Line 2408: แมวของฉันชอบนอนอยู่ข้างหน้าต่างเพื่อรับแสงแดด
#
# Cosine similarity: 0.99
# Line 1058: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 2270: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.99
# Line 576: การทำงานเป็นทีมจะทำให้เราสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 1258: ถ้าเราทำงานเป็นทีม เราจะสามารถบรรลุเป้าหมายได้เร็วขึ้น
#
# Cosine similarity: 0.99
# Line 311: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดี
# Line 1183: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.99
# Line 311: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดี
# Line 1969: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.99
# Line 1158: เขาเป็นคนตลกและทำให้ทุกคนหัวเราะได้เสมอ
# Line 1519: เขาเป็นคนตลกและมักจะทำให้ทุกคนหัวเราะ
#
# Cosine similarity: 0.99
# Line 1847: หลังจากออกกำลังกาย ฉันรู้สึกสดชื่นขึ้นมาก
# Line 2027: หลังจากที่ฉันออกกำลังกายเสร็จ ฉันรู้สึกสดชื่นมาก
#
# Cosine similarity: 0.99
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1223: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1391: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้รู้สึกผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 1004: แม้ว่างานจะยาก แต่ฉันก็จะทำให้ดีที่สุดเท่าที่จะทำได้
# Line 1116: ถึงแม้ว่างานจะยาก แต่ฉันก็จะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.99
# Line 32: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีอะไรแนะนำไหม
# Line 1242: ฉันกำลังมองหาของขวัญที่พิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 0.99
# Line 2385: เขาทำงานหนักมากจนเหนื่อยโหมไปทั้งตัว
# Line 2398: เขาทำงานหนักมากจนเหนื่อยโผนไปทั้งตัว
#
# Cosine similarity: 0.99
# Line 699: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 2274: การฟังเพลงโปรดช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
#
# Cosine similarity: 0.99
# Line 532: คุณคิดว่าอะไรคือสิ่งที่ทำให้ชีวิตมีความหมายที่สุด?
# Line 2499: คุณคิดว่าอะไรคือสิ่งที่ทำให้ชีวิตมีความหมาย
#
# Cosine similarity: 0.99
# Line 1183: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 2255: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่แข็งแรงขึ้น
#
# Cosine similarity: 0.99
# Line 1969: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 2255: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่แข็งแรงขึ้น
#
# Cosine similarity: 0.99
# Line 538: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 2016: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.99
# Line 1748: แม่ค้าที่ร้านขายของชำมักจะจัดของให้เป็นระเบียบ และติดป้ายราคาชัดเจน
# Line 1785: แม่ค้าที่ร้านขายของชำจัดร้านเป็นระเบียบ และติดป้ายราคาชัดเจน
#
# Cosine similarity: 0.99
# Line 74: ถ้าเราช่วยเหลือผู้อื่น โลกนี้ก็จะน่าอยู่ขึ้นสำหรับทุกคน
# Line 1431: ถ้าเราช่วยเหลือผู้อื่น โลกจะน่าอยู่ยิ่งขึ้น
#
# Cosine similarity: 0.99
# Line 98: ถ้าเรามองโลกในแง่บวก ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
# Line 1678: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
#
# Cosine similarity: 0.99
# Line 1649: ถ้าคุณพร้อมแล้ว เราสามารถเริ่มการประชุมได้ทันที
# Line 1943: ถ้าคุณพร้อมแล้ว เราจะเริ่มประชุมได้ทันที
#
# Cosine similarity: 0.99
# Line 872: แม้ว่างานจะยากและท้าทาย แต่ฉันก็จะพยายามทำให้ดีที่สุดเท่าที่ฉันจะทำได้
# Line 1004: แม้ว่างานจะยาก แต่ฉันก็จะทำให้ดีที่สุดเท่าที่จะทำได้
#
# Cosine similarity: 0.99
# Line 1398: ถ้าคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
# Line 1643: หากคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ตลอดเวลา
#
# Cosine similarity: 0.99
# Line 32: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีอะไรแนะนำไหม
# Line 2039: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 0.99
# Line 1731: แม่ค้าที่ร้านขายของชำมักจะจดจำลูกค้าประจำได้ และชอบพูดคุยอย่างเป็นกันเอง
# Line 1762: แม่ค้าที่ร้านขายของชำมักจะจดจำลูกค้าประจำได้ และทักทายอย่างเป็นกันเอง
#
# Cosine similarity: 0.99
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1927: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ผ่อนคลาย
#
# Cosine similarity: 0.98
# Line 311: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดี
# Line 2255: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่แข็งแรงขึ้น
#
# Cosine similarity: 0.98
# Line 903: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
# Line 1463: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.98
# Line 365: ฉันกำลังฝึกทักษะการพูดในที่สาธารณะ เพื่อพัฒนาความมั่นใจและศักยภาพตัวเอง
# Line 912: ฉันกำลังฝึกพูดในที่สาธารณะ เพื่อเพิ่มความมั่นใจและทักษะการสื่อสาร
#
# Cosine similarity: 0.98
# Line 1130: เมื่อไหร่ที่คุณพร้อม เราจะเริ่มประชุมได้ทันที
# Line 1943: ถ้าคุณพร้อมแล้ว เราจะเริ่มประชุมได้ทันที
#
# Cosine similarity: 0.98
# Line 1632: เธอกำลังฝึกเล่นกีตาร์เพื่อแสดงในงานคอนเสิร์ตของโรงเรียน
# Line 2446: เธอกำลังฝึกเล่นกีตาร์เพื่อแสดงในงานโรงเรียน
#
# Cosine similarity: 0.98
# Line 1247: ฉันชอบไปเดินเล่นริมชายหาดเพื่อฟังเสียงคลื่นและสัมผัสลมทะเล
# Line 2109: ฉันชอบเดินเล่นริมชายหาด และฟังเสียงคลื่นทะเล
#
# Cosine similarity: 0.98
# Line 1703: ฉันหวังว่าเราจะมีโอกาสได้ร่วมงานกันอีกในอนาคต
# Line 1992: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้อีกในอนาคต
#
# Cosine similarity: 0.98
# Line 297: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 997: ถ้าเราวางแผนการเงินอย่างดี เราจะมีความมั่นคงในอนาคต
#
# Cosine similarity: 0.98
# Line 1084: ฉันกำลังเรียนรู้วิธีการถ่ายภาพ เพื่อที่จะเก็บความทรงจำที่สวยงาม
# Line 1441: ฉันอยากเรียนรู้วิธีถ่ายภาพ เพื่อเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.98
# Line 951: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
# Line 1592: ฉันชอบฟังเพลงขณะทำงานเพราะมันช่วยให้ฉันมีสมาธิมากขึ้น
#
# Cosine similarity: 0.98
# Line 601: ถ้าเราใส่ใจสุขภาพ เราก็จะมีชีวิตที่ยืนยาวและมีความสุข
# Line 2481: ถ้าเราดูแลสุขภาพให้ดี เราจะมีชีวิตที่ยืนยาวและมีความสุข
#
# Cosine similarity: 0.98
# Line 1726: แม่ค้าที่ร้านผลไม้มักจะคัดผลไม้อย่างดี และขายในราคาที่เป็นธรรม
# Line 1736: แม่ค้าที่ขายผลไม้มักจะคัดเลือกผลไม้อย่างดี แต่ขายในราคาที่เป็นธรรม
#
# Cosine similarity: 0.98
# Line 1242: ฉันกำลังมองหาของขวัญที่พิเศษสำหรับวันเกิดของแม่
# Line 1606: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีคำแนะนำไหม
#
# Cosine similarity: 0.98
# Line 318: การใช้เวลาร่วมกับครอบครัวเป็นสิ่งที่มีคุณค่าและสำคัญมาก
# Line 1666: การใช้เวลาคุณภาพกับครอบครัวเป็นสิ่งที่มีค่าและสำคัญมาก
#
# Cosine similarity: 0.98
# Line 1409: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
# Line 2270: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.98
# Line 1735: คุณครูวิทยาศาสตร์สอนให้เรารู้จักสังเกตธรรมชาติ และทำการทดลองอย่างระมัดระวัง
# Line 1761: คุณครูวิทยาศาสตร์สอนให้เรารู้จักสังเกตธรรมชาติ และทำการทดลองอย่างปลอดภัย
#
# Cosine similarity: 0.98
# Line 742: การสื่อสารที่ดีเป็นสิ่งสำคัญในการทำงานเป็นทีม
# Line 1413: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีม
#
# Cosine similarity: 0.98
# Line 1074: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 2011: การทำงานร่วมกันทำให้เราบรรลุเป้าหมายได้เร็วขึ้น
#
# Cosine similarity: 0.98
# Line 1425: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
# Line 1639: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.98
# Line 1606: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่ คุณมีคำแนะนำไหม
# Line 2039: ฉันกำลังมองหาของขวัญพิเศษสำหรับวันเกิดของแม่
#
# Cosine similarity: 0.98
# Line 304: เธอกำลังฝึกซ้อมอย่างหนักเพื่อการแข่งขันที่จะมาถึง
# Line 1298: เธอกำลังฝึกซ้อมเพื่อการแข่งขันครั้งสำคัญที่กำลังจะมาถึง
#
# Cosine similarity: 0.98
# Line 94: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิและทำงานได้มีประสิทธิภาพมากขึ้น
# Line 1463: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.98
# Line 988: ถ้าเราร่วมมือกัน เราจะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 1074: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
#
# Cosine similarity: 0.98
# Line 957: ถ้าเราออกเดินทางตอนนี้ เราจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
# Line 2403: ถ้าเรารีบออกเดินทางตอนนี้ เราอาจจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.98
# Line 1235: ฉันเชื่อว่าความพยายามและความอดทนจะนำพาเราไปสู่ความสำเร็จ
# Line 2275: ฉันเชื่อว่าความพยายามและความตั้งใจจะนำพาเราไปสู่ความสำเร็จ
#
# Cosine similarity: 0.98
# Line 567: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
# Line 2288: ถ้าเรารักษาสิ่งแวดล้อมโลกของเราก็จะน่าอยู่มากขึ้น
#
# Cosine similarity: 0.98
# Line 1009: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
# Line 2288: ถ้าเรารักษาสิ่งแวดล้อมโลกของเราก็จะน่าอยู่มากขึ้น
#
# Cosine similarity: 0.98
# Line 1322: แม้ว่าจะเหนื่อย แต่เธอก็ยังพยายามทำงานต่อไปโดยไม่ย่อท้อ
# Line 1354: แม้ว่าจะเหนื่อย แต่เธอก็ไม่เคยท้อถอยกับการทำงาน
#
# Cosine similarity: 0.98
# Line 1148: เขากำลังฝึกฝนอย่างหนักเพื่อเตรียมตัวสำหรับการแข่งขัน
# Line 1544: เขากำลังฝึกซ้อมอย่างหนักเพื่อการแข่งขันครั้งสำคัญ
#
# Cosine similarity: 0.98
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 1503: ผมชอบฟังเพลงขณะขับรถเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 0.98
# Line 957: ถ้าเราออกเดินทางตอนนี้ เราจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
# Line 1114: ถ้าเราออกเดินทางตอนนี้ เราน่าจะไปถึงก่อนพระอาทิตย์ตก
#
# Cosine similarity: 0.98
# Line 1025: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
# Line 1425: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 1148: เขากำลังฝึกฝนอย่างหนักเพื่อเตรียมตัวสำหรับการแข่งขัน
# Line 1395: เขากำลังฝึกซ้อมอย่างหนัก เพื่อเตรียมตัวสำหรับการแข่งขันครั้งต่อไป
#
# Cosine similarity: 0.98
# Line 555: ถ้าเราประหยัดเงินวันนี้ อนาคตเราก็จะมีความมั่นคงทางการเงิน
# Line 2250: ถ้าเราประหยัดเงินตั้งแต่วันนี้อนาคตเราจะมีความมั่นคงขึ้น
#
# Cosine similarity: 0.98
# Line 1334: ร้านบล็อกเชนคาเฟ่แห่งนี้มีการตกแต่งที่ทันสมัยและน่าสนใจมาก
# Line 1360: ร้านบล็อกเชนคาเฟ่นี้มีบรรยากาศที่ทันสมัยและน่าสนใจ
#
# Cosine similarity: 0.98
# Line 463: คุณมีแผนอะไรสำหรับวันหยุดยาวที่กำลังจะมาถึง?
# Line 690: คุณวางแผนจะทำอะไรในวันหยุดยาวที่จะถึงนี้?
#
# Cosine similarity: 0.98
# Line 699: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 2478: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่เหน็ดเหนื่อย
#
# Cosine similarity: 0.98
# Line 692: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 2094: ถ้าเราทำงานร่วมกัน เราจะสามารถทำงานนี้ให้เสร็จเร็วขึ้น
#
# Cosine similarity: 0.98
# Line 1975: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 2094: ถ้าเราทำงานร่วมกัน เราจะสามารถทำงานนี้ให้เสร็จเร็วขึ้น
#
# Cosine similarity: 0.98
# Line 1535: ฉันต้องการเวลาสักครู่เพื่อคิดเกี่ยวกับข้อเสนอของคุณ
# Line 1648: ฉันต้องการเวลาในการคิดเกี่ยวกับข้อเสนอนี้สักหน่อย
#
# Cosine similarity: 0.98
# Line 1280: เธอมีความฝันที่จะเป็นนักเขียนและกำลังเขียนหนังสือเล่มแรกของเธอ
# Line 1430: เธอฝันอยากเป็นนักเขียนและกำลังเริ่มเขียนนิยายเล่มแรก
#
# Cosine similarity: 0.98
# Line 1309: เมื่อเราเปิดใจรับฟังผู้อื่น เราก็จะเรียนรู้มากขึ้น
# Line 1434: เมื่อเราเปิดใจรับฟังความคิดเห็นของผู้อื่น เราจะเรียนรู้มากขึ้น
#
# Cosine similarity: 0.98
# Line 1114: ถ้าเราออกเดินทางตอนนี้ เราน่าจะไปถึงก่อนพระอาทิตย์ตก
# Line 1387: ถ้าเราออกเดินทางตอนนี้ เราจะไปถึงจุดหมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.98
# Line 538: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 1486: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.98
# Line 707: วันนี้ฉันลืมกุญแจบ้านไว้ที่ทำงาน ต้องกลับไปเอา
# Line 1024: ฉันลืมกุญแจบ้านไว้ที่ทำงาน ทำให้ต้องกลับไปเอาอีกครั้งหนึ่ง
#
# Cosine similarity: 0.98
# Line 936: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
# Line 1486: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.98
# Line 1667: ฉันอยากเรียนรู้การเล่นเปียโน เพราะชอบเสียงเพลงที่ไพเราะ
# Line 2310: ฉันอยากจะเรียนรู้การเล่นเปียโนเพราะชอบเสียงดนตรี
#
# Cosine similarity: 0.98
# Line 872: แม้ว่างานจะยากและท้าทาย แต่ฉันก็จะพยายามทำให้ดีที่สุดเท่าที่ฉันจะทำได้
# Line 1116: ถึงแม้ว่างานจะยาก แต่ฉันก็จะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.98
# Line 1233: เขาเป็นคนที่มีน้ำใจและมักจะช่วยเหลือผู้อื่นเสมอเมื่อมีโอกาส
# Line 1555: เขาเป็นคนที่ใจดีและมักจะช่วยเหลือผู้อื่นเสมอ
#
# Cosine similarity: 0.98
# Line 1964: แม้ว่าจะมีอุปสรรคมากมาย เราก็ไม่ควรยอมแพ้
# Line 2092: แม้ว่าจะมีอุปสรรคมากมาย แต่เราจะไม่ยอมแพ้
#
# Cosine similarity: 0.98
# Line 300: เมื่อเรามองโลกในแง่ดี ชีวิตก็จะสดใสและมีความสุขมากขึ้น
# Line 2266: ถ้าเรามองโลกในแง่ดีชีวิตก็จะมีความสุขมากขึ้น
#
# Cosine similarity: 0.98
# Line 1011: เราสามารถเรียนรู้จากความผิดพลาดเพื่อพัฒนาตัวเองต่อไป
# Line 2459: เราควรเรียนรู้จากความผิดพลาดเพื่อพัฒนาตนเอง
#
# Cosine similarity: 0.98
# Line 1387: ถ้าเราออกเดินทางตอนนี้ เราจะไปถึงจุดหมายก่อนพระอาทิตย์ตกดิน
# Line 2403: ถ้าเรารีบออกเดินทางตอนนี้ เราอาจจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.98
# Line 620: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1425: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 1622: ฉันอยากเรียนทำอาหารไทยเพื่อที่จะทำให้ครอบครัวทานที่บ้าน
# Line 2409: ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำอาหารให้ครอบครัวทาน
#
# Cosine similarity: 0.98
# Line 1291: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
# Line 1425: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 742: การสื่อสารที่ดีเป็นสิ่งสำคัญในการทำงานเป็นทีม
# Line 1082: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.98
# Line 742: การสื่อสารที่ดีเป็นสิ่งสำคัญในการทำงานเป็นทีม
# Line 1660: การสื่อสารที่ดีเป็นกุญแจสำคัญในการทำงานเป็นทีมอย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.98
# Line 297: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 589: การวางแผนการเงินจะช่วยให้เรามีอนาคตที่มั่นคงและปลอดภัย
#
# Cosine similarity: 0.98
# Line 303: การอ่านข่าวทุกวันทำให้เราทันเหตุการณ์และรอบรู้มากขึ้น
# Line 2296: การอ่านข่าวทุกวันช่วยให้เราทันสมัยและรู้ทันเหตุการณ์
#
# Cosine similarity: 0.98
# Line 587: ถ้าเรารับฟังความคิดเห็นของผู้อื่น เราก็จะเข้าใจพวกเขามากขึ้น
# Line 2305: การฟังความคิดเห็นของผู้อื่นจะช่วยให้เราเข้าใจมากขึ้น
#
# Cosine similarity: 0.98
# Line 733: ฉันเชื่อว่าการศึกษาเป็นกุญแจสำคัญสู่ความสำเร็จ
# Line 1106: ฉันเชื่อว่าการศึกษาเป็นกุญแจสู่ความสำเร็จในชีวิต
#
# Cosine similarity: 0.98
# Line 2141: คุณพ่อชอบฟังเพลงแจ๊สแบบโบราณขณะทำงานไม้ในโรงรถช่วงสุดสัปดาห์
# Line 2150: คุณพ่อชอบฟังเพลงแจ๊สคลาสสิกขณะทำงานไม้ในโรงรถวันหยุด
#
# Cosine similarity: 0.98
# Line 1195: ฉันชอบฟังเสียงคลื่นทะเลเวลาที่ไปเที่ยวชายหาด
# Line 2109: ฉันชอบเดินเล่นริมชายหาด และฟังเสียงคลื่นทะเล
#
# Cosine similarity: 0.98
# Line 2150: คุณพ่อชอบฟังเพลงแจ๊สคลาสสิกขณะทำงานไม้ในโรงรถวันหยุด
# Line 2156: คุณพ่อชอบทำงานไม้ไปฟังเพลงแจ๊สโบราณในโรงรถช่วงวันหยุดสุดสัปดาห์
#
# Cosine similarity: 0.98
# Line 769: เมื่อวานฉันเจอเพื่อนเก่าที่ห้างโดยบังเอิญ
# Line 1935: วันนี้ฉันพบเพื่อนเก่าโดยบังเอิญที่ห้างสรรพสินค้า
#
# Cosine similarity: 0.98
# Line 2144: เด็กนักเรียนกำลังทดลองวิทยาศาสตร์กับฟลูออรีนในห้องแล็บภายใต้การดูแล
# Line 2148: เด็กนักเรียนกำลังทดลองวิทยาศาสตร์กับฟลูออรีนภายใต้การดูแลอย่างใกล้ชิด
#
# Cosine similarity: 0.98
# Line 1195: ฉันชอบฟังเสียงคลื่นทะเลเวลาที่ไปเที่ยวชายหาด
# Line 2260: ฉันชอบฟังเสียงคลื่นทะเลเวลานั่งพักผ่อนบนชายหาด
#
# Cosine similarity: 0.98
# Line 314: การฟังความคิดเห็นของผู้อื่นทำให้เราเข้าใจและเรียนรู้มากขึ้น
# Line 2305: การฟังความคิดเห็นของผู้อื่นจะช่วยให้เราเข้าใจมากขึ้น
#
# Cosine similarity: 0.98
# Line 310: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1425: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตขึ้น
#
# Cosine similarity: 0.98
# Line 1524: ผมอยากเรียนรู้ภาษาใหม่เพื่อเปิดโลกทัศน์มากขึ้น
# Line 2441: ฉันชอบเรียนรู้ภาษาใหม่เพื่อเปิดโลกทัศน์ของตัวเอง
#
# Cosine similarity: 0.98
# Line 1574: ผมกำลังหาหนังสือที่ดีสักเล่มเพื่ออ่านในวันหยุด
# Line 2429: ฉันกำลังหาหนังสือเล่มใหม่ที่จะอ่านในวันหยุดนี้
#
# Cosine similarity: 0.98
# Line 539: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกภูมิใจที่ได้ทำงานสำเร็จตามเป้าหมาย
# Line 1924: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกพอใจที่ได้ทำงานสำเร็จ
#
# Cosine similarity: 0.98
# Line 42: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญ ที่จะทำให้เราเติบโตและพัฒนา
# Line 1639: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.98
# Line 2: วันนี้อากาศดีมาก ฉันคิดว่าเราควรออกไปเดินเล่นที่สวนสาธารณะด้วยกันไหม
# Line 1910: วันนี้อากาศดีมาก เราน่าจะไปเดินเล่นที่สวนสาธารณะกันไหม?
#
# Cosine similarity: 0.98
# Line 695: ฉันต้องการฝึกฝนการพูดในที่สาธารณะเพื่อเพิ่มความมั่นใจ
# Line 912: ฉันกำลังฝึกพูดในที่สาธารณะ เพื่อเพิ่มความมั่นใจและทักษะการสื่อสาร
#
# Cosine similarity: 0.98
# Line 1625: แม้ว่าจะมีอุปสรรคมากมาย แต่เราต้องไม่ยอมแพ้และเดินหน้าต่อไป
# Line 2092: แม้ว่าจะมีอุปสรรคมากมาย แต่เราจะไม่ยอมแพ้
#
# Cosine similarity: 0.98
# Line 94: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิและทำงานได้มีประสิทธิภาพมากขึ้น
# Line 1099: การฟังเพลงคลาสสิกช่วยให้ฉันสงบและมีสมาธิในการทำงาน
#
# Cosine similarity: 0.98
# Line 19: ฉันอยากเรียนรู้ภาษาใหม่ เพราะจะได้สื่อสารกับคนต่างชาติได้ดีขึ้น
# Line 2026: ฉันเรียนภาษาใหม่ เพราะอยากสื่อสารกับคนต่างชาติ
#
# Cosine similarity: 0.98
# Line 1409: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับได้ง่ายขึ้น
# Line 1486: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.98
# Line 979: แม้ว่าจะมีอุปสรรคมากมาย แต่ฉันก็จะไม่ยอมแพ้ต่อความฝันของฉัน
# Line 1214: ถึงแม้ว่าจะยากลำบาก แต่ฉันก็จะไม่ยอมแพ้ต่อความฝัน
#
# Cosine similarity: 0.98
# Line 17: ถึงแม้ว่าเราจะพบกับอุปสรรคมากมาย แต่ก็ไม่ควรยอมแพ้และควรสู้ต่อไป
# Line 1964: แม้ว่าจะมีอุปสรรคมากมาย เราก็ไม่ควรยอมแพ้
#
# Cosine similarity: 0.98
# Line 607: การอ่านข่าวทุกวันจะช่วยให้เราทันเหตุการณ์และรอบรู้มากขึ้น
# Line 2296: การอ่านข่าวทุกวันช่วยให้เราทันสมัยและรู้ทันเหตุการณ์
#
# Cosine similarity: 0.98
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 548: ฉันชอบฟังเพลงเวลาขับรถ เพราะทำให้การเดินทางสนุกสนานขึ้น
#
# Cosine similarity: 0.98
# Line 676: การนั่งสมาธิช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิมากขึ้น
# Line 999: ฉันพบว่าการนั่งสมาธิช่วยให้จิตใจสงบและมีสมาธิมากขึ้น
#
# Cosine similarity: 0.98
# Line 907: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญที่ช่วยให้เราเติบโตและพัฒนา
# Line 1639: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 1291: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
# Line 1639: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 780: ฉันชอบฟังเพลงเวลาทำงานเพราะช่วยให้มีสมาธิ
# Line 951: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 33: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
# Line 1824: ถึงแม้ว่าจะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
#
# Cosine similarity: 0.97
# Line 310: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1639: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 94: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิและทำงานได้มีประสิทธิภาพมากขึ้น
# Line 903: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
#
# Cosine similarity: 0.97
# Line 1500: ฉันต้องการซื้อของขวัญให้เพื่อนแต่ยังไม่รู้ว่าจะซื้ออะไรดี
# Line 1630: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่แน่ใจว่าเขาจะชอบอะไร
#
# Cosine similarity: 0.97
# Line 1622: ฉันอยากเรียนทำอาหารไทยเพื่อที่จะทำให้ครอบครัวทานที่บ้าน
# Line 2226: ตอนนี้ฉันกำลังเรียนทำอาหารไทยเพราะอยากทำให้ครอบครัวทาน
#
# Cosine similarity: 0.97
# Line 588: ฉันชอบดื่มกาแฟตอนเช้า มันช่วยให้ฉันตื่นตัวและพร้อมสำหรับวันใหม่
# Line 2405: ฉันชอบดื่มกาแฟในตอนเช้าเพราะมันทำให้ฉันตื่นตัว
#
# Cosine similarity: 0.97
# Line 1210: เราควรจะสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจของเรา
# Line 2465: พวกเราควรสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจที่ยั่งยืน
#
# Cosine similarity: 0.97
# Line 9: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้ฉันรู้สึกผ่อนคลายและสนุกสนาน
# Line 2037: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางสนุกขึ้น
#
# Cosine similarity: 0.97
# Line 1330: คุณหมอแนะนำให้พักผ่อนและไม่ควรโหมงานหนักจนเกินไป
# Line 1348: หมอแนะนำว่าไม่ควรโหมงานหนักเกินไป ควรพักผ่อนให้เพียงพอ
#
# Cosine similarity: 0.97
# Line 297: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 1424: การวางแผนทางการเงินที่ดีจะช่วยให้เรามีความมั่นคง
#
# Cosine similarity: 0.97
# Line 620: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1639: เมื่อเราเรียนรู้จากความผิดพลาด เราจะเติบโตและพัฒนายิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 1029: ถึงแม้ว่าเขาจะอายุน้อย แต่เขาก็มีประสบการณ์ในการทำงานมากมาย
# Line 1122: แม้ว่าเขาจะอายุน้อย แต่เขาก็มีประสบการณ์มากมาย
#
# Cosine similarity: 0.97
# Line 860: ฉันชอบอ่านหนังสือทุกคืนก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายมากขึ้น
# Line 936: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 1924: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกพอใจที่ได้ทำงานสำเร็จ
# Line 2059: แม้ว่าวันนี้จะยุ่ง แต่ฉันก็รู้สึกมีความสุขที่ได้ทำงาน
#
# Cosine similarity: 0.97
# Line 17: ถึงแม้ว่าเราจะพบกับอุปสรรคมากมาย แต่ก็ไม่ควรยอมแพ้และควรสู้ต่อไป
# Line 1625: แม้ว่าจะมีอุปสรรคมากมาย แต่เราต้องไม่ยอมแพ้และเดินหน้าต่อไป
#
# Cosine similarity: 0.97
# Line 1025: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
# Line 1291: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและเข้มแข็งขึ้น
#
# Cosine similarity: 0.97
# Line 1539: ถ้าคุณพร้อมแล้วเราจะเริ่มประชุมกันตอนนี้เลย
# Line 1943: ถ้าคุณพร้อมแล้ว เราจะเริ่มประชุมได้ทันที
#
# Cosine similarity: 0.97
# Line 1074: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 2436: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 2293: ถ้าเราช่วยกันรักษาความสะอาดชุมชนของเราก็จะน่าอยู่ขึ้น
# Line 2486: ถ้าเราช่วยกันรักษาความสะอาด สังคมของเราจะน่าอยู่ขึ้น
#
# Cosine similarity: 0.97
# Line 1720: แม่มักจะสอนให้เราประหยัดน้ำประหยัดไฟ และใช้ทรัพยากรอย่างคุ้มค่า
# Line 1757: แม่มักจะสอนให้เรารู้จักประหยัดน้ำประหยัดไฟ และรักษาสิ่งแวดล้อม
#
# Cosine similarity: 0.97
# Line 627: แม้ว่าฉันจะมีงานยุ่ง แต่ฉันก็จะหาเวลาให้ครอบครัวเสมอ
# Line 1193: แม้ว่าฉันจะยุ่ง แต่ฉันก็จะหาเวลาให้กับครอบครัว
#
# Cosine similarity: 0.97
# Line 984: ฉันเชื่อว่าการอ่านหนังสือจะเปิดโลกทัศน์และเพิ่มความรู้ให้เรา
# Line 1189: ฉันคิดว่าการอ่านหนังสือทำให้เราเปิดโลกทัศน์กว้างขึ้น
#
# Cosine similarity: 0.97
# Line 310: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1025: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 264: เมื่อคืนฝนตกหนักมาก ทำให้ถนนลื่นและต้องขับรถอย่างระมัดระวัง
# Line 938: เมื่อวานนี้ฝนตกหนักมาก ทำให้ถนนลื่นและต้องขับรถอย่างระมัดระวัง
#
# Cosine similarity: 0.97
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 279: การอ่านหนังสือก่อนนอนช่วยให้หลับสบายและฝันดี
#
# Cosine similarity: 0.97
# Line 33: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
# Line 1508: แม้ว่าวันนี้จะยุ่งแต่ฉันก็มีความสุขที่ได้ช่วยเหลือคนอื่น
#
# Cosine similarity: 0.97
# Line 1630: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่แน่ใจว่าเขาจะชอบอะไร
# Line 2093: ฉันต้องการซื้อของขวัญให้เพื่อน แต่ไม่รู้ว่าจะเลือกอะไรดี
#
# Cosine similarity: 0.97
# Line 538: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 860: ฉันชอบอ่านหนังสือทุกคืนก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายมากขึ้น
#
# Cosine similarity: 0.97
# Line 980: ฉันชอบนั่งอ่านหนังสือที่ร้านกาแฟ เพราะบรรยากาศที่เงียบสงบ
# Line 1016: ฉันชอบอ่านหนังสือที่ร้านกาแฟ เพราะบรรยากาศเงียบสงบและมีกลิ่นหอมของกาแฟ
#
# Cosine similarity: 0.97
# Line 1210: เราควรจะสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจของเรา
# Line 1701: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อช่วยเศรษฐกิจของชุมชน
#
# Cosine similarity: 0.97
# Line 43: ถ้าเรารักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่มากขึ้นสำหรับคนรุ่นต่อไป
# Line 2288: ถ้าเรารักษาสิ่งแวดล้อมโลกของเราก็จะน่าอยู่มากขึ้น
#
# Cosine similarity: 0.97
# Line 1395: เขากำลังฝึกซ้อมอย่างหนัก เพื่อเตรียมตัวสำหรับการแข่งขันครั้งต่อไป
# Line 1544: เขากำลังฝึกซ้อมอย่างหนักเพื่อการแข่งขันครั้งสำคัญ
#
# Cosine similarity: 0.97
# Line 1587: เราควรตรวจสอบข้อมูลอีกครั้งเพื่อความแน่ใจก่อนส่งมอบ
# Line 1967: เราควรตรวจสอบข้อมูลอีกครั้งเพื่อความถูกต้องก่อนส่ง
#
# Cosine similarity: 0.97
# Line 680: ฉันต้องการเรียนรู้การถ่ายภาพเพื่อเก็บความทรงจำที่ดี
# Line 1441: ฉันอยากเรียนรู้วิธีถ่ายภาพ เพื่อเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.97
# Line 906: ถ้าเรามองโลกในแง่ดี ชีวิตของเราก็จะเต็มไปด้วยพลังและความหวัง
# Line 1678: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
#
# Cosine similarity: 0.97
# Line 42: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญ ที่จะทำให้เราเติบโตและพัฒนา
# Line 1025: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 26: ฉันตั้งใจว่าจะเริ่มออกกำลังกายทุกเช้า เพื่อสุขภาพที่ดีและร่างกายที่แข็งแรง
# Line 1327: ฉันจึงตัดสินใจเริ่มออกกำลังกายทุกเช้า เพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.97
# Line 1281: เมื่อเราช่วยเหลือผู้อื่น เราก็จะรู้สึกดีและโลกจะน่าอยู่ขึ้น
# Line 1431: ถ้าเราช่วยเหลือผู้อื่น โลกจะน่าอยู่ยิ่งขึ้น
#
# Cosine similarity: 0.97
# Line 1116: ถึงแม้ว่างานจะยาก แต่ฉันก็จะพยายามทำให้ดีที่สุด
# Line 1842: ถึงแม้ว่าจะยาก แต่ฉันจะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.97
# Line 620: ถ้าเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1025: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 638: การเปิดใจรับฟังความคิดเห็นของผู้อื่น จะทำให้เราเติบโตและพัฒนา
# Line 1704: การเปิดใจรับฟังความคิดเห็นที่แตกต่างจะช่วยให้เราเติบโตขึ้น
#
# Cosine similarity: 0.97
# Line 907: การเรียนรู้จากความผิดพลาดเป็นสิ่งสำคัญที่ช่วยให้เราเติบโตและพัฒนา
# Line 1025: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและพัฒนาตนเองได้มากขึ้น
#
# Cosine similarity: 0.97
# Line 903: การฟังเพลงคลาสสิกช่วยให้ฉันรู้สึกผ่อนคลายและมีสมาธิในการทำงาน
# Line 2234: ฉันชอบฟังเพลงคลาสสิกเวลาทำงานเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 1315: งานนี้ยากกว่าที่คิดไว้มาก แต่ฉันจะพยายามทำให้ดีที่สุดและไม่ย่อท้อ
# Line 1341: งานนี้ยากกว่าที่คิดไว้ แต่ฉันจะพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.97
# Line 95: ถ้าเราดูแลสิ่งแวดล้อม โลกของเราก็จะสวยงามและยั่งยืนสำหรับคนรุ่นหลัง
# Line 271: เราควรรักษาสิ่งแวดล้อมเพื่อให้โลกของเรายังคงสวยงามสำหรับคนรุ่นหลัง
#
# Cosine similarity: 0.97
# Line 1217: เมื่อวานนี้ฝนตกหนักมากแต่ฉันยังคงต้องออกไปทำงานตามปกติ
# Line 1385: แม้ว่าวันนี้ฝนจะตกหนัก แต่ฉันก็ยังต้องไปทำงานตามปกติ
#
# Cosine similarity: 0.97
# Line 1393: ฉันต้องการซื้อของขวัญพิเศษให้กับน้องสาวในวันเกิดของเธอ
# Line 1936: ฉันกำลังมองหาของขวัญวันเกิดที่เหมาะสมสำหรับน้องสาว
#
# Cosine similarity: 0.97
# Line 1820: ถ้าคุณต้องการความช่วยเหลือ คุณสามารถโทรหาฉันได้ตลอดเวลา
# Line 2020: ถ้าเธอต้องการความช่วยเหลือ โปรดโทรหาฉันได้ทุกเวลา
#
# Cosine similarity: 0.97
# Line 1486: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 1130: เมื่อไหร่ที่คุณพร้อม เราจะเริ่มประชุมได้ทันที
# Line 1649: ถ้าคุณพร้อมแล้ว เราสามารถเริ่มการประชุมได้ทันที
#
# Cosine similarity: 0.97
# Line 879: การฟังเพลงโปรดระหว่างการทำงาน ช่วยให้ฉันมีสมาธิและทำงานได้อย่างมีประสิทธิภาพ
# Line 951: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 892: ฉันอยากเรียนรู้การถ่ายภาพ เพื่อบันทึกความทรงจำและช่วงเวลาที่สวยงามในชีวิต
# Line 1441: ฉันอยากเรียนรู้วิธีถ่ายภาพ เพื่อเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.97
# Line 1239: ถ้าคุณสนใจ เราสามารถจัดการประชุมเพื่อหารือรายละเอียดเพิ่มเติม
# Line 1499: ถ้าคุณสนใจเราสามารถจัดการประชุมเพิ่มเติมได้
#
# Cosine similarity: 0.97
# Line 566: การอ่านหนังสือทำให้เราเปิดใจกว้างและเข้าใจโลกมากขึ้น
# Line 1189: ฉันคิดว่าการอ่านหนังสือทำให้เราเปิดโลกทัศน์กว้างขึ้น
#
# Cosine similarity: 0.97
# Line 1270: ฉันหวังว่าจะได้พบคุณอีกครั้งในอนาคตอันใกล้นี้
# Line 1396: ฉันหวังว่าเราจะมีโอกาสได้พบกันอีกครั้งในอนาคตอันใกล้นี้
#
# Cosine similarity: 0.97
# Line 365: ฉันกำลังฝึกทักษะการพูดในที่สาธารณะ เพื่อพัฒนาความมั่นใจและศักยภาพตัวเอง
# Line 695: ฉันต้องการฝึกฝนการพูดในที่สาธารณะเพื่อเพิ่มความมั่นใจ
#
# Cosine similarity: 0.97
# Line 698: ถ้าคุณพร้อมแล้ว เราจะออกเดินทางกันตอนนี้เลย
# Line 1190: ถ้าคุณพร้อมแล้ว เราจะเริ่มเดินทางกันทันที
#
# Cosine similarity: 0.97
# Line 279: การอ่านหนังสือก่อนนอนช่วยให้หลับสบายและฝันดี
# Line 1058: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 879: การฟังเพลงโปรดระหว่างการทำงาน ช่วยให้ฉันมีสมาธิและทำงานได้อย่างมีประสิทธิภาพ
# Line 1592: ฉันชอบฟังเพลงขณะทำงานเพราะมันช่วยให้ฉันมีสมาธิมากขึ้น
#
# Cosine similarity: 0.97
# Line 578: ฉันชอบเดินเล่นริมชายหาด ฟังเสียงคลื่นและสูดอากาศบริสุทธิ์
# Line 1247: ฉันชอบไปเดินเล่นริมชายหาดเพื่อฟังเสียงคลื่นและสัมผัสลมทะเล
#
# Cosine similarity: 0.97
# Line 589: การวางแผนการเงินจะช่วยให้เรามีอนาคตที่มั่นคงและปลอดภัย
# Line 997: ถ้าเราวางแผนการเงินอย่างดี เราจะมีความมั่นคงในอนาคต
#
# Cosine similarity: 0.97
# Line 1625: แม้ว่าจะมีอุปสรรคมากมาย แต่เราต้องไม่ยอมแพ้และเดินหน้าต่อไป
# Line 1964: แม้ว่าจะมีอุปสรรคมากมาย เราก็ไม่ควรยอมแพ้
#
# Cosine similarity: 0.97
# Line 1058: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
# Line 1486: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
#
# Cosine similarity: 0.97
# Line 2094: ถ้าเราทำงานร่วมกัน เราจะสามารถทำงานนี้ให้เสร็จเร็วขึ้น
# Line 2436: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 545: เมื่อวานนี้ฉันได้ลองทำสูตรอาหารใหม่ และผลลัพธ์ก็ออกมาอร่อยมาก
# Line 691: ฉันลองทำสูตรอาหารใหม่และผลลัพธ์ออกมาอร่อยมาก
#
# Cosine similarity: 0.97
# Line 1705: คุณมีคำแนะนำอย่างไรในการพัฒนาทักษะการสื่อสารของฉัน
# Line 2273: คุณมีคำแนะนำอย่างไรบ้างในการพัฒนาทักษะการสื่อสาร
#
# Cosine similarity: 0.97
# Line 1678: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
# Line 2266: ถ้าเรามองโลกในแง่ดีชีวิตก็จะมีความสุขมากขึ้น
#
# Cosine similarity: 0.97
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 1058: การอ่านหนังสือก่อนนอนช่วยให้ฉันนอนหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 1114: ถ้าเราออกเดินทางตอนนี้ เราน่าจะไปถึงก่อนพระอาทิตย์ตก
# Line 2403: ถ้าเรารีบออกเดินทางตอนนี้ เราอาจจะถึงที่หมายก่อนพระอาทิตย์ตกดิน
#
# Cosine similarity: 0.97
# Line 936: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายขึ้น
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 738: เราควรสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจในชุมชน
# Line 1210: เราควรจะสนับสนุนสินค้าท้องถิ่นเพื่อเศรษฐกิจของเรา
#
# Cosine similarity: 0.97
# Line 1486: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
# Line 2270: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 589: การวางแผนการเงินจะช่วยให้เรามีอนาคตที่มั่นคงและปลอดภัย
# Line 1982: เราควรวางแผนการเงินให้ดีเพื่ออนาคตที่มั่นคง
#
# Cosine similarity: 0.97
# Line 35: ถ้าคุณต้องการความช่วยเหลือเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
# Line 1398: ถ้าคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
#
# Cosine similarity: 0.97
# Line 971: ถ้าเราแบ่งงานกันทำ เราจะเสร็จเร็วขึ้นและมีเวลาพักผ่อนมากขึ้น
# Line 1141: ถ้าเราแบ่งงานกันทำ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.97
# Line 74: ถ้าเราช่วยเหลือผู้อื่น โลกนี้ก็จะน่าอยู่ขึ้นสำหรับทุกคน
# Line 1281: เมื่อเราช่วยเหลือผู้อื่น เราก็จะรู้สึกดีและโลกจะน่าอยู่ขึ้น
#
# Cosine similarity: 0.97
# Line 2274: การฟังเพลงโปรดช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 2478: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่เหน็ดเหนื่อย
#
# Cosine similarity: 0.97
# Line 610: ฉันอยากเรียนรู้การเล่นดนตรี เพราะมันเป็นวิธีที่ดีในการแสดงออก
# Line 925: ฉันตั้งใจจะเรียนรู้การเล่นดนตรี เพราะมันเป็นวิธีที่ดีในการแสดงออกและผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 692: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 2436: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 1975: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 2436: ถ้าเราทำงานร่วมกัน เราจะสำเร็จได้เร็วขึ้น
#
# Cosine similarity: 0.97
# Line 300: เมื่อเรามองโลกในแง่ดี ชีวิตก็จะสดใสและมีความสุขมากขึ้น
# Line 1678: ถ้าเรามองโลกในแง่ดี ชีวิตก็จะเต็มไปด้วยความสุขและความหวัง
#
# Cosine similarity: 0.97
# Line 1172: ฉันกำลังฝึกเล่นโยคะเพื่อสุขภาพกายและใจที่ดีขึ้น
# Line 2292: ฉันกำลังฝึกฝนการเล่นโยคะเพื่อสุขภาพที่ดีและจิตใจที่สงบ
#
# Cosine similarity: 0.97
# Line 997: ถ้าเราวางแผนการเงินอย่างดี เราจะมีความมั่นคงในอนาคต
# Line 1982: เราควรวางแผนการเงินให้ดีเพื่ออนาคตที่มั่นคง
#
# Cosine similarity: 0.97
# Line 297: การวางแผนการเงินที่ดีจะช่วยให้เรามีความมั่นคงในอนาคต
# Line 1982: เราควรวางแผนการเงินให้ดีเพื่ออนาคตที่มั่นคง
#
# Cosine similarity: 0.97
# Line 1031: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางไม่เหงา
# Line 2037: ฉันชอบฟังเพลงขณะขับรถ เพราะมันทำให้การเดินทางสนุกขึ้น
#
# Cosine similarity: 0.97
# Line 279: การอ่านหนังสือก่อนนอนช่วยให้หลับสบายและฝันดี
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 463: คุณมีแผนอะไรสำหรับวันหยุดยาวที่กำลังจะมาถึง?
# Line 2091: คุณมีแผนสำหรับวันหยุดยาวนี้หรือยัง
#
# Cosine similarity: 0.97
# Line 1521: ถ้ามีปัญหาอะไรคุณสามารถโทรหาฉันได้ตลอดเวลา
# Line 1820: ถ้าคุณต้องการความช่วยเหลือ คุณสามารถโทรหาฉันได้ตลอดเวลา
#
# Cosine similarity: 0.97
# Line 1486: ฉันชอบอ่านหนังสือก่อนนอนเพราะมันช่วยให้หลับง่ายขึ้น
# Line 2016: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 292: ฉันตั้งใจว่าจะเรียนภาษาใหม่เพื่อเปิดโอกาสในการทำงานมากขึ้น
# Line 1445: ฉันสนใจที่จะเรียนรู้ภาษาใหม่ เพื่อเปิดโอกาสในงานอาชีพ
#
# Cosine similarity: 0.97
# Line 617: ฉันชอบนั่งอ่านหนังสือในคาเฟ่ มันเป็นบรรยากาศที่ผ่อนคลาย
# Line 980: ฉันชอบนั่งอ่านหนังสือที่ร้านกาแฟ เพราะบรรยากาศที่เงียบสงบ
#
# Cosine similarity: 0.97
# Line 522: คุณมีวิธีการจัดการกับความเครียดอย่างไรบ้าง?
# Line 1952: คุณมีคำแนะนำในการจัดการกับความเครียดไหม?
#
# Cosine similarity: 0.97
# Line 1389: หลังจากที่เราเสร็จงานนี้แล้ว เราควรฉลองด้วยกันสักหน่อยดีไหม
# Line 2106: หลังจากที่เราเสร็จงานนี้แล้ว เรามาฉลองกันเถอะ
#
# Cosine similarity: 0.97
# Line 1000: ถ้าเรามีความมุ่งมั่นและความพยายาม เราจะสามารถทำได้ทุกอย่าง
# Line 2103: ถ้าเรามีความตั้งใจ เราจะสามารถทำได้ทุกอย่าง
#
# Cosine similarity: 0.97
# Line 29: ฉันชอบดื่มกาแฟทุกเช้า เพราะมันช่วยให้ฉันตื่นตัวและพร้อมเริ่มงาน
# Line 588: ฉันชอบดื่มกาแฟตอนเช้า มันช่วยให้ฉันตื่นตัวและพร้อมสำหรับวันใหม่
#
# Cosine similarity: 0.97
# Line 538: ฉันชอบอ่านหนังสือก่อนนอน เพราะทำให้ผ่อนคลายและหลับสบายขึ้น
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 56: เธอเคยลองเล่นโยคะหรือไม่ มันช่วยให้ร่างกายและจิตใจแข็งแรงขึ้น
# Line 2052: เธอเคยลองเล่นโยคะไหม มันช่วยให้ร่างกายและจิตใจผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 1941: การอ่านหนังสือก่อนนอนช่วยให้ฉันหลับสบายขึ้น
#
# Cosine similarity: 0.97
# Line 316: การดูแลต้นไม้และดอกไม้ช่วยให้ฉันรู้สึกผ่อนคลายและมีความสุข
# Line 1104: การดูแลต้นไม้และดอกไม้เป็นงานอดิเรกที่ทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 1308: ฉันเชื่อว่าความเมตตาและความเอื้อเฟื้อเผื่อแผ่สามารถเปลี่ยนแปลงโลกได้
# Line 2496: ฉันเชื่อว่าความเมตตาสามารถเปลี่ยนแปลงโลกได้
#
# Cosine similarity: 0.97
# Line 680: ฉันต้องการเรียนรู้การถ่ายภาพเพื่อเก็บความทรงจำที่ดี
# Line 1084: ฉันกำลังเรียนรู้วิธีการถ่ายภาพ เพื่อที่จะเก็บความทรงจำที่สวยงาม
#
# Cosine similarity: 0.97
# Line 899: ฉันเพิ่งเริ่มฝึกโยคะ และพบว่ามันช่วยให้ฉันมีสุขภาพที่ดีทั้งกายและใจ
# Line 2467: ฉันเพิ่งเริ่มเรียนโยคะและรู้สึกว่ามันดีต่อร่างกายและจิตใจ
#
# Cosine similarity: 0.97
# Line 860: ฉันชอบอ่านหนังสือทุกคืนก่อนนอน เพราะมันช่วยให้ฉันผ่อนคลายและหลับสบายมากขึ้น
# Line 2016: ฉันชอบอ่านหนังสือก่อนนอน เพราะมันทำให้ฉันผ่อนคลาย
#
# Cosine similarity: 0.97
# Line 1132: ถ้าอากาศดี เราไปปิกนิกที่ชายหาดกันเถอะ
# Line 1392: ถ้าวันนี้อากาศดี เราจะไปปิกนิกที่ชายหาดกันไหม
#
# Cosine similarity: 0.97
# Line 1332: มีคนมาร้านเยอะมากในช่วงจัดโปรโมชั่นพิเศษ
# Line 1379: วันนี้มีคนมาร้านเยอะมากเพราะมีโปรโมชั่นพิเศษ
#
# Cosine similarity: 0.97
# Line 18: เมื่อไหร่ที่คุณมีปัญหา สามารถปรึกษาฉันได้เสมอ ฉันยินดีที่จะช่วยเหลือ
# Line 2229: ถ้าคุณมีปัญหาอะไรสามารถบอกฉันได้ฉันยินดีช่วยเหลือเสมอ
#
# Cosine similarity: 0.97
# Line 563: แม้ว่าวันนี้จะเหนื่อย แต่ฉันก็รู้สึกดีที่ได้ช่วยเหลือผู้อื่น
# Line 1824: ถึงแม้ว่าจะเหนื่อย แต่ฉันก็มีความสุขที่ได้ช่วยเหลือผู้อื่น
#
# Cosine similarity: 0.96
# Line 34: การอ่านหนังสือก่อนนอนจะช่วยให้เราผ่อนคลายและนอนหลับสบายขึ้น
# Line 2270: ฉันคิดว่าการอ่านหนังสือก่อนนอนช่วยให้หลับสบายขึ้น
#
# Cosine similarity: 0.96
# Line 713: การอ่านข่าวทุกเช้าช่วยให้ฉันรู้เท่าทันสถานการณ์ปัจจุบัน
# Line 1096: การอ่านข่าวทุกเช้าทำให้ฉันทันเหตุการณ์และรู้เรื่องราวรอบโลก
#
# Cosine similarity: 0.96
# Line 2273: คุณมีคำแนะนำอย่างไรบ้างในการพัฒนาทักษะการสื่อสาร
# Line 2458: คุณมีคำแนะนำสำหรับการปรับปรุงทักษะการสื่อสารหรือไม่
#
# Cosine similarity: 0.96
# Line 314: การฟังความคิดเห็นของผู้อื่นทำให้เราเข้าใจและเรียนรู้มากขึ้น
# ...
# Line 76: เธอมีสถานที่ท่องเที่ยวที่อยากไปบ้างไหม เราอาจวางแผนไปด้วยกันได้
# Line 2060: ถ้าเธอพร้อมแล้ว เราออกเดินทางกันเลยดีไหม
#
# Cosine similarity: 0.90
# Line 1091: การวางแผนที่ดีจะช่วยให้เราสามารถจัดการเวลาและทรัพยากรได้อย่างมีประสิทธิภาพ
# Line 2466: การวางแผนล่วงหน้าจะช่วยให้เราทำงานได้อย่างมีประสิทธิภาพ
#
# Cosine similarity: 0.90
# Line 1398: ถ้าคุณมีคำถามเพิ่มเติม กรุณาติดต่อฉันได้ทุกเมื่อ
# Line 2430: ถ้าคุณมีคำถาม สามารถถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 727: ถ้าคุณพร้อม เราจะเริ่มการนำเสนอได้เลย
# Line 1539: ถ้าคุณพร้อมแล้วเราจะเริ่มประชุมกันตอนนี้เลย
#
# Cosine similarity: 0.90
# Line 533: วันนี้อากาศดีมาก แต่พรุ่งนี้อาจจะฝนตก เราควรเตรียมร่มไปด้วยนะ
# Line 2105: คุณคิดว่าฝนจะตกหรือไม่ ฉันควรพกร่มไปด้วยไหม
#
# Cosine similarity: 0.90
# Line 1080: เขาชอบอ่านหนังสือวิทยาศาสตร์ เพื่อเรียนรู้เกี่ยวกับจักรวาลและธรรมชาติ
# Line 1474: ฉันชอบอ่านหนังสือเกี่ยวกับจักรวาลและดาราศาสตร์
#
# Cosine similarity: 0.90
# Line 18: เมื่อไหร่ที่คุณมีปัญหา สามารถปรึกษาฉันได้เสมอ ฉันยินดีที่จะช่วยเหลือ
# Line 2430: ถ้าคุณมีคำถาม สามารถถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 49: การฟังเพลงโปรดช่วยให้ฉันรู้สึกดีขึ้นในวันที่เหนื่อยล้า
# Line 1418: เมื่อเราฟังเพลงที่ชอบ จะช่วยให้เรารู้สึกดีขึ้น
#
# Cosine similarity: 0.90
# Line 138: ถ้าอยากสุขภาพดีควรกินผักให้มากและออกกำลังกายสม่ำเสมอ
# Line 1237: เราควรดูแลสุขภาพของตนเองโดยการออกกำลังกายและกินอาหารที่มีประโยชน์
#
# Cosine similarity: 0.90
# Line 746: การตั้งเป้าหมายที่ชัดเจนช่วยให้เราบรรลุสิ่งที่ต้องการ
# Line 1295: เมื่อเรามีเป้าหมายที่ชัดเจน เราก็จะมุ่งมั่นและไม่หลงทาง
#
# Cosine similarity: 0.90
# Line 965: เราควรไปเยี่ยมชมพิพิธภัณฑ์ศิลปะ เพราะมีนิทรรศการที่น่าสนใจ
# Line 1970: ถ้าคุณมีเวลาว่าง เราไปดูนิทรรศการศิลปะกันไหม?
#
# Cosine similarity: 0.90
# Line 263: ในช่วงวันหยุดยาวนี้ ฉันอยากไปเที่ยวทะเลและพักผ่อนริมชายหาด
# Line 2407: ถ้าคุณมีเวลาว่างสุดสัปดาห์นี้ เราไปเที่ยวทะเลกันไหม
#
# Cosine similarity: 0.90
# Line 7: เธอช่วยอธิบายวิธีการใช้โปรแกรมนี้ให้ฉันฟังอีกครั้งได้ไหม ฉันยังไม่ค่อยเข้าใจ
# Line 781: คุณช่วยสอนวิธีใช้แอปนี้ให้ฉันหน่อยได้ไหม
#
# Cosine similarity: 0.90
# Line 461: เมื่อเช้านี้ผมไปวิ่งที่สวน และรู้สึกสดชื่นมากขึ้น
# Line 2241: เมื่อฉันมีเวลาว่างฉันมักจะไปวิ่งที่สวนเพื่อสุขภาพที่ดีขึ้น
#
# Cosine similarity: 0.90
# Line 873: ฉันเชื่อว่าการดูแลสุขภาพด้วยการออกกำลังกายและกินอาหารที่มีประโยชน์ สำคัญต่อการมีชีวิตที่ดี
# Line 1646: การกินอาหารที่มีประโยชน์เป็นสิ่งสำคัญสำหรับสุขภาพที่ดี
#
# Cosine similarity: 0.90
# Line 1576: ฉันอยากลองทำอาหารสูตรใหม่ที่พบในอินเทอร์เน็ต
# Line 2056: ฉันอยากลองทำอาหารสูตรใหม่ ที่เห็นในรายการทีวี
#
# Cosine similarity: 0.90
# Line 568: การฟังเพลงช่วยให้ฉันผ่อนคลายและสร้างสมาธิในการทำงาน
# Line 2274: การฟังเพลงโปรดช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
#
# Cosine similarity: 0.90
# Line 1491: เราไม่ควรเสียเวลาอีกต่อไป มาเริ่มงานกันเถอะ
# Line 2071: เรามีเวลาจำกัด ดังนั้นเราควรเริ่มงานทันที
#
# Cosine similarity: 0.90
# Line 923: ถ้าเรารู้จักการบริหารความเครียด เราก็จะมีชีวิตที่สมดุลและมีสุขภาพจิตที่ดี
# Line 1458: ถ้าเราดูแลสุขภาพกายและใจ ชีวิตก็จะสมดุลและมีความสุข
#
# Cosine similarity: 0.90
# Line 3: แม้ว่าฝนจะตกหนัก แต่ฉันก็ยังต้องไปทำงานเพราะมีการประชุมสำคัญที่ต้องเข้าร่วม
# Line 1715: แม้ว่าฝนจะตกหนัก แต่พวกเราก็ยังต้องออกไปทำงานตามปกติ
#
# Cosine similarity: 0.90
# Line 691: ฉันลองทำสูตรอาหารใหม่และผลลัพธ์ออกมาอร่อยมาก
# Line 1159: ฉันอยากลองทำอาหารสูตรใหม่ที่เห็นในอินเตอร์เน็ต
#
# Cosine similarity: 0.90
# Line 308: ถ้าเรามีความกรุณาและเอาใจใส่ต่อผู้อื่น โลกจะน่าอยู่ขึ้น
# Line 567: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
#
# Cosine similarity: 0.90
# Line 308: ถ้าเรามีความกรุณาและเอาใจใส่ต่อผู้อื่น โลกจะน่าอยู่ขึ้น
# Line 1009: ถ้าเราช่วยกันรักษาสิ่งแวดล้อม โลกของเราก็จะน่าอยู่ขึ้น
#
# Cosine similarity: 0.90
# Line 697: ฉันอยากเรียนรู้การทำสวนเพื่อปลูกผักและผลไม้เอง
# Line 1156: ฉันวางแผนจะปลูกผักสวนครัวเองที่บ้าน
#
# Cosine similarity: 0.90
# Line 951: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
# Line 1463: การฟังเพลงคลาสสิกช่วยให้ฉันมีสมาธิในการทำงาน
#
# Cosine similarity: 0.90
# Line 938: เมื่อวานนี้ฝนตกหนักมาก ทำให้ถนนลื่นและต้องขับรถอย่างระมัดระวัง
# Line 2227: ฤดูฝนปีนี้ฝนตกบ่อยมากทำให้ถนนลื่นต้องระวังเวลาเดินทาง
#
# Cosine similarity: 0.90
# Line 1183: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 2443: ฉันตั้งใจว่าจะออกกำลังกายทุกวันแต่บางครั้งก็ขี้เกียจ
#
# Cosine similarity: 0.90
# Line 1969: ฉันตั้งใจว่าจะออกกำลังกายทุกวันเพื่อสุขภาพที่ดีขึ้น
# Line 2443: ฉันตั้งใจว่าจะออกกำลังกายทุกวันแต่บางครั้งก็ขี้เกียจ
#
# Cosine similarity: 0.90
# Line 50: ถ้าเรามีความตั้งใจจริง ไม่ว่าอะไรก็สามารถทำได้สำเร็จ
# Line 881: ถ้าเรามีความพยายามและไม่ยอมแพ้ เราก็จะสามารถบรรลุเป้าหมายที่ตั้งไว้ได้
#
# Cosine similarity: 0.90
# Line 691: ฉันลองทำสูตรอาหารใหม่และผลลัพธ์ออกมาอร่อยมาก
# Line 1039: ฉันกำลังพยายามทำอาหารสูตรใหม่ แต่ดูเหมือนว่าจะต้องฝึกฝนอีกมาก
#
# Cosine similarity: 0.90
# Line 448: ถ้าคุณว่างวันเสาร์นี้ เราไปดูหนังเรื่องใหม่ด้วยกันดีไหม?
# Line 2276: คุณอยากไปดูหนังเรื่องใหม่ที่เข้าฉายสุดสัปดาห์นี้กับฉันไหม
#
# Cosine similarity: 0.90
# Line 28: ในช่วงวันหยุดยาวนี้ เราวางแผนจะไปเที่ยวต่างจังหวัดกับครอบครัว
# Line 1467: ฉันวางแผนจะเดินทางไปเยี่ยมเพื่อนที่ต่างจังหวัดในวันหยุดนี้
#
# Cosine similarity: 0.90
# Line 1698: การรับฟังความคิดเห็นของผู้อื่นช่วยให้เรามีมุมมองที่กว้างขึ้น
# Line 1704: การเปิดใจรับฟังความคิดเห็นที่แตกต่างจะช่วยให้เราเติบโตขึ้น
#
# Cosine similarity: 0.90
# Line 881: ถ้าเรามีความพยายามและไม่ยอมแพ้ เราก็จะสามารถบรรลุเป้าหมายที่ตั้งไว้ได้
# Line 1390: ถึงแม้ว่ามันจะยาก แต่ถ้าเราพยายาม เราก็จะประสบความสำเร็จได้
#
# Cosine similarity: 0.90
# Line 473: คุณคิดว่าวันหยุดนี้เราควรไปเที่ยวภูเขาหรือทะเลดี?
# Line 981: ถ้าคุณต้องการพักผ่อน เราสามารถไปเที่ยวทะเลหรือภูเขาก็ได้
#
# Cosine similarity: 0.90
# Line 1146: ฉันเพิ่งเรียนรู้วิธีการทำขนมเค้กสูตรใหม่ที่อร่อยมาก
# Line 1638: เธอสามารถสอนฉันทำขนมเค้กสูตรนี้ได้ไหม มันดูน่าอร่อยมาก
#
# Cosine similarity: 0.90
# Line 1187: ถึงแม้ว่าฝนจะตกหนัก แต่เราก็ยังไปเที่ยวได้
# Line 2073: แม้ว่าสภาพอากาศจะไม่ดี แต่เรายังคงเดินทางต่อไปได้
#
# Cosine similarity: 0.90
# Line 1000: ถ้าเรามีความมุ่งมั่นและความพยายาม เราจะสามารถทำได้ทุกอย่าง
# Line 2022: แม้ว่างานจะยาก แต่ถ้าเราพยายาม เราจะสำเร็จได้
#
# Cosine similarity: 0.90
# Line 1588: ผมหวังว่าจะได้พบคุณอีกครั้งในโอกาสหน้า
# Line 2104: ฉันดีใจที่ได้พบคุณอีกครั้ง หลังจากเวลาผ่านไปนาน
#
# Cosine similarity: 0.90
# Line 1914: หลังจากที่ฝนหยุดตก เราควรออกไปซื้อของที่ตลาดไหม?
# Line 2239: ถึงแม้ว่าฝนจะตกเราก็ยังสามารถไปช็อปปิ้งที่ห้างสรรพสินค้าได้
#
# Cosine similarity: 0.90
# Line 277: ความสุขไม่ได้อยู่ที่ว่าเรามีอะไร แต่อยู่ที่ว่าเรารู้สึกอย่างไรกับสิ่งที่มี
# Line 2468: ความสุขไม่ใช่สิ่งที่หาได้จากภายนอก แต่เป็นสิ่งที่อยู่ภายในใจเรา
#
# Cosine similarity: 0.90
# Line 468: ถ้าคุณต้องการความช่วยเหลือ ผมยินดีที่จะช่วยเสมอ
# Line 975: ฉันรู้สึกขอบคุณสำหรับการสนับสนุนและความช่วยเหลือจากคุณเสมอมา
#
# Cosine similarity: 0.90
# Line 105: เมื่อวานฉันไปซื้อผักที่ตลาดและพบเพื่อนเก่าที่ไม่ได้เจอกันนาน
# Line 535: เมื่อวานนี้ฉันไปเดินเล่นที่สวนสาธารณะ แล้วพบกับเพื่อนเก่าที่ไม่ได้เจอกันนาน
#
# Cosine similarity: 0.90
# Line 864: แม้ว่าวันนี้อากาศจะร้อนมาก แต่ฉันก็ยังออกไปวิ่งออกกำลังกายตามปกติเพื่อสุขภาพที่ดี
# Line 1231: แม้ว่าอากาศจะร้อน แต่เขาก็ยังคงวิ่งออกกำลังกายทุกเช้า
#
# Cosine similarity: 0.90
# Line 1340: ในที่สุดฉันก็ได้ลองทำเค้กช็อกโกแลตสูตรของคุณยายที่เก็บไว้นาน
# Line 1368: คุณแม่สอนทำเค้กช็อกโกแลตสูตรโบราณของครอบครัว
#
# Cosine similarity: 0.90
# Line 715: ฉันพบว่าโยคะช่วยให้ฉันมีสมาธิและผ่อนคลาย
# Line 999: ฉันพบว่าการนั่งสมาธิช่วยให้จิตใจสงบและมีสมาธิมากขึ้น
#
# Cosine similarity: 0.90
# Line 778: เมื่อไหร่ที่คุณว่าง เราควรคุยเรื่องโครงการใหม่
# Line 1983: คุณต้องการนัดพบกันเพื่อหารือเรื่องโครงการใหม่หรือไม่?
#
# Cosine similarity: 0.90
# Line 1328: ถ้าคุณว่างเย็นนี้ เรามาดูหนังด้วยกันเถอะ มีหนังใหม่น่าสนใจหลายเรื่อง
# Line 1484: หากคุณมีเวลาว่างเราน่าจะไปดูหนังด้วยกัน
#
# Cosine similarity: 0.90
# Line 1434: เมื่อเราเปิดใจรับฟังความคิดเห็นของผู้อื่น เราจะเรียนรู้มากขึ้น
# Line 1704: การเปิดใจรับฟังความคิดเห็นที่แตกต่างจะช่วยให้เราเติบโตขึ้น
#
# Cosine similarity: 0.90
# Line 900: ถ้าเราตั้งเป้าหมายและมุ่งมั่นทำงานหนัก เราก็จะสามารถประสบความสำเร็จได้ตามที่หวัง
# Line 2022: แม้ว่างานจะยาก แต่ถ้าเราพยายาม เราจะสำเร็จได้
#
# Cosine similarity: 0.90
# Line 66: การอ่านหนังสือหลากหลายแนวช่วยเปิดโลกทัศน์และความคิดสร้างสรรค์
# Line 566: การอ่านหนังสือทำให้เราเปิดใจกว้างและเข้าใจโลกมากขึ้น
#
# Cosine similarity: 0.90
# Line 1654: คุณต้องการให้ฉันช่วยอะไรไหม ฉันยินดีที่จะช่วยเต็มที่
# Line 2007: คุณต้องการให้ฉันช่วยอะไรเพิ่มเติมหรือไม่?
#
# Cosine similarity: 0.90
# Line 299: ฉันชอบดื่มชาร้อนกับขนมปังปิ้งในตอนเช้า
# Line 731: ฉันชอบดื่มชาเขียวร้อนในตอนเช้าเพื่อเริ่มต้นวันใหม่
#
# Cosine similarity: 0.90
# Line 38: ฉันรู้สึกซาบซึ้งในความมีน้ำใจของคุณ ที่คอยช่วยเหลือฉันเสมอมา
# Line 1682: ฉันอยากขอบคุณคุณสำหรับความช่วยเหลือและการสนับสนุนที่ต่อเนื่อง
#
# Cosine similarity: 0.90
# Line 1923: การออกกำลังกายเป็นประจำช่วยให้สุขภาพดีขึ้น คุณคิดอย่างไร?
# Line 2230: การออกกำลังกายทุกวันช่วยให้สุขภาพแข็งแรงและจิตใจแจ่มใส
#
# Cosine similarity: 0.90
# Line 13: ถ้าเราต้องการประสบความสำเร็จ เราควรตั้งเป้าหมายและพยายามอย่างเต็มที่เพื่อให้ไปถึง
# Line 86: ถ้าเรามีเป้าหมายที่ชัดเจน เราก็จะมุ่งมั่นและพยายามได้ง่ายขึ้น
#
# Cosine similarity: 0.90
# Line 906: ถ้าเรามองโลกในแง่ดี ชีวิตของเราก็จะเต็มไปด้วยพลังและความหวัง
# Line 1453: เมื่อเรามีทัศนคติที่ดี ชีวิตก็จะมีความสุขมากขึ้น
#
# Cosine similarity: 0.90
# Line 974: ถ้าคุณไม่สะดวกที่จะพบกันวันนี้ เราสามารถนัดใหม่วันอื่นได้
# Line 1620: ถ้าวันนี้คุณยุ่ง เราสามารถเลื่อนการประชุมไปเป็นวันพรุ่งนี้ได้
#
# Cosine similarity: 0.90
# Line 576: การทำงานเป็นทีมจะทำให้เราสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 692: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.90
# Line 576: การทำงานเป็นทีมจะทำให้เราสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 1975: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.90
# Line 1200: ฉันชอบปลูกต้นไม้และดูแลสวนในเวลาว่าง
# Line 1455: ฉันชอบปลูกต้นไม้และดอกไม้ในสวน เพราะทำให้บ้านสวยงาม
#
# Cosine similarity: 0.90
# Line 310: เมื่อเราเรียนรู้จากความผิดพลาด เราก็จะเติบโตและแข็งแกร่งขึ้น
# Line 1155: แม้ว่าเราจะเคยผิดพลาด แต่เราก็เรียนรู้จากมันได้
#
# Cosine similarity: 0.90
# Line 1101: ฉันหวังว่าคุณจะสนุกกับการเดินทางครั้งนี้และเก็บประสบการณ์ที่ดี
# Line 2245: การเดินทางครั้งนี้จะเป็นประสบการณ์ที่ดีสำหรับพวกเราทุกคน
#
# Cosine similarity: 0.90
# Line 1120: ถ้าคุณมีคำถามเกี่ยวกับงาน โปรดติดต่อฉันได้ตลอดเวลา
# Line 2430: ถ้าคุณมีคำถาม สามารถถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 962: ถ้าคุณต้องการความช่วยเหลือในการทำงาน โปรดบอกฉันได้เลย
# Line 1226: ถ้าเธอต้องการความช่วยเหลือ โปรดอย่าลังเลที่จะบอกฉัน
#
# Cosine similarity: 0.90
# Line 539: แม้ว่าวันนี้จะยุ่งมาก แต่ฉันก็รู้สึกภูมิใจที่ได้ทำงานสำเร็จตามเป้าหมาย
# Line 1508: แม้ว่าวันนี้จะยุ่งแต่ฉันก็มีความสุขที่ได้ช่วยเหลือคนอื่น
#
# Cosine similarity: 0.90
# Line 500: ผมพบร้านอาหารใหม่ที่อาหารอร่อยมาก คุณต้องลองไป
# Line 1602: คุณควรลองร้านอาหารใหม่ที่เปิดตรงมุมถนน อาหารอร่อยมาก
#
# Cosine similarity: 0.90
# Line 932: ฉันชอบการฟังเสียงฝนตก เพราะมันทำให้ฉันรู้สึกสงบและผ่อนคลาย
# Line 1142: ฉันชอบฟังเสียงฝนตกเวลาที่นอนพักผ่อนอยู่บ้าน
#
# Cosine similarity: 0.90
# Line 292: ฉันตั้งใจว่าจะเรียนภาษาใหม่เพื่อเปิดโอกาสในการทำงานมากขึ้น
# Line 1947: ฉันคิดว่าการเรียนรู้ภาษาใหม่เป็นการเปิดโอกาสให้กับชีวิต
#
# Cosine similarity: 0.90
# Line 550: วันนี้ฉันตื่นเช้าเพื่อไปวิ่งออกกำลังกาย และรู้สึกสดชื่นมากตลอดวัน
# Line 1847: หลังจากออกกำลังกาย ฉันรู้สึกสดชื่นขึ้นมาก
#
# Cosine similarity: 0.90
# Line 7: เธอช่วยอธิบายวิธีการใช้โปรแกรมนี้ให้ฉันฟังอีกครั้งได้ไหม ฉันยังไม่ค่อยเข้าใจ
# Line 2244: คุณช่วยอธิบายปัญหานี้ให้ฉันฟังอีกครั้งได้ไหมฉันยังไม่เข้าใจ
#
# Cosine similarity: 0.90
# Line 665: ฉันกำลังหัดเล่นกีตาร์ แต่ยังไม่เก่งเท่าไหร่
# Line 1986: ฉันเพิ่งเริ่มเรียนเล่นกีตาร์ และมันท้าทายมากแต่สนุก
#
# Cosine similarity: 0.90
# Line 915: ฉันสนใจในการศึกษาประวัติศาสตร์ เพื่อเข้าใจถึงรากฐานและความเป็นมาของสังคม
# Line 2099: ฉันสนใจเรียนรู้เกี่ยวกับวัฒนธรรมและประวัติศาสตร์
#
# Cosine similarity: 0.90
# Line 187: เธอควรลองทำอาหารไทยสูตรดั้งเดิมดูจะได้รู้รสชาติแท้แท้
# Line 1517: เธอกำลังเรียนรู้วิธีการทำอาหารไทยแบบดั้งเดิม
#
# Cosine similarity: 0.90
# Line 77: การออกไปเดินชมธรรมชาติช่วยให้จิตใจสงบและลดความเครียด
# Line 986: เมื่อฉันรู้สึกเครียด ฉันมักจะออกไปเดินเล่นเพื่อผ่อนคลายจิตใจ
#
# Cosine similarity: 0.90
# Line 873: ฉันเชื่อว่าการดูแลสุขภาพด้วยการออกกำลังกายและกินอาหารที่มีประโยชน์ สำคัญต่อการมีชีวิตที่ดี
# Line 1023: การออกกำลังกายเป็นประจำเป็นสิ่งสำคัญสำหรับสุขภาพที่ดีและชีวิตที่ยืนยาว
#
# Cosine similarity: 0.90
# Line 951: ฉันชอบฟังเพลงขณะทำงาน เพราะมันช่วยให้ฉันมีสมาธิและทำงานได้เร็วขึ้น
# Line 2234: ฉันชอบฟังเพลงคลาสสิกเวลาทำงานเพราะทำให้ผ่อนคลาย
#
# Cosine similarity: 0.90
# Line 569: แม้ว่าเส้นทางจะยากลำบาก แต่ฉันก็จะไม่ยอมแพ้และจะเดินหน้าต่อไป
# Line 591: แม้ว่าฉันจะผิดหวัง แต่ฉันก็จะไม่ยอมแพ้และจะพยายามต่อไป
#
# Cosine similarity: 0.90
# Line 17: ถึงแม้ว่าเราจะพบกับอุปสรรคมากมาย แต่ก็ไม่ควรยอมแพ้และควรสู้ต่อไป
# Line 1222: แม้ว่าจะมีอุปสรรคมากมาย เรายังคงมุ่งมั่นที่จะประสบความสำเร็จ
#
# Cosine similarity: 0.90
# Line 324: ฉันชอบชมพระจันทร์เต็มดวงที่ส่องแสงสว่างบนท้องฟ้ายามค่ำคืน
# Line 1436: ฉันสนใจเรื่องดาราศาสตร์และชอบดูดาวในคืนที่ท้องฟ้าแจ่มใส
#
# Cosine similarity: 0.90
# Line 605: ถ้าคุณมีคำถาม อย่าลังเลที่จะถาม ฉันยินดีที่จะตอบ
# Line 1980: ถ้าคุณมีข้อสงสัย โปรดอย่าลังเลที่จะถามฉันได้ตลอดเวลา
#
# Cosine similarity: 0.90
# Line 1072: เมื่อฤดูหนาวมาเยือน อากาศก็เย็นลงและใบไม้ก็เริ่มเปลี่ยนสี
# Line 1414: ฉันชอบอากาศเย็นของฤดูใบไม้ร่วงและสีสันของใบไม้ที่เปลี่ยนไป
#
# Cosine similarity: 0.90
# Line 19: ฉันอยากเรียนรู้ภาษาใหม่ เพราะจะได้สื่อสารกับคนต่างชาติได้ดีขึ้น
# Line 292: ฉันตั้งใจว่าจะเรียนภาษาใหม่เพื่อเปิดโอกาสในการทำงานมากขึ้น
#
# Cosine similarity: 0.90
# Line 1089: ถ้าคุณรู้สึกไม่สบายใจ โปรดบอกฉัน ฉันพร้อมที่จะช่วยเหลือ
# Line 1147: ถ้าคุณต้องการความช่วยเหลือ โปรดบอกฉันได้เลย
#
# Cosine similarity: 0.90
# Line 865: การเรียนภาษาใหม่ไม่ใช่เรื่องง่าย แต่ถ้าเราฝึกฝนอย่างสม่ำเสมอ เราก็จะเก่งขึ้นได้
# Line 1400: การเรียนรู้ภาษาใหม่ต้องใช้เวลาและความพยายามอย่างมาก
#
# Cosine similarity: 0.90
# Line 494: ฉันอยากลองทำขนมไทยแบบดั้งเดิม แต่ต้องหาสูตรก่อน
# Line 2089: ฉันเพิ่งเรียนรู้สูตรขนมใหม่ และอยากลองทำดู
#
# Cosine similarity: 0.90
# Line 267: พรุ่งนี้อย่าลืมนำเอกสารสำคัญมาประชุมด้วยนะครับ
# Line 362: วันนี้มีประชุมสำคัญตอนบ่าย อย่าลืมเตรียมข้อมูลให้ครบถ้วนนะ
#
# Cosine similarity: 0.90
# Line 1558: เธอกำลังเรียนรู้ที่จะเล่นกีตาร์และทำได้ดีมาก
# Line 1632: เธอกำลังฝึกเล่นกีตาร์เพื่อแสดงในงานคอนเสิร์ตของโรงเรียน
#
# Cosine similarity: 0.90
# Line 1371: มาเที่ยวสวนสาธารณะกันเถอะ อากาศดีมาก
# Line 1531: ถ้าอากาศดีเราควรจัดปิกนิกที่สวนสาธารณะ
#
# Cosine similarity: 0.90
# Line 977: เธออยากไปเรียนโยคะกับฉันไหม มันช่วยผ่อนคลายและดีต่อสุขภาพ
# Line 1658: ฉันอยากลองฝึกโยคะเพื่อเสริมสร้างสุขภาพกายและจิตใจ
#
# Cosine similarity: 0.90
# Line 258: ถ้าคุณมีเวลาว่างพรุ่งนี้ เราไปดูหนังเรื่องใหม่ที่เพิ่งเข้าฉายกันเถอะ
# Line 448: ถ้าคุณว่างวันเสาร์นี้ เราไปดูหนังเรื่องใหม่ด้วยกันดีไหม?
#
# Cosine similarity: 0.90
# Line 36: ฉันหวังว่าเราจะได้มีโอกาสทำงานร่วมกันอีกในอนาคต
# Line 2001: ฉันตั้งตารอคอยวันที่เราจะได้ทำงานร่วมกันอีกครั้ง
#
# Cosine similarity: 0.90
# Line 1234: ถ้าเราเริ่มต้นตั้งแต่ตอนนี้ เราจะมีเวลามากพอที่จะทำงานเสร็จ
# Line 1491: เราไม่ควรเสียเวลาอีกต่อไป มาเริ่มงานกันเถอะ
#
# Cosine similarity: 0.90
# Line 24: ฉันกำลังคิดจะซื้อต้นไม้มาปลูกในบ้าน เพื่อเพิ่มความสดชื่นและความสวยงาม
# Line 1455: ฉันชอบปลูกต้นไม้และดอกไม้ในสวน เพราะทำให้บ้านสวยงาม
#
# Cosine similarity: 0.90
# Line 1110: ถ้าเธอว่างพรุ่งนี้ เราไปเดินเล่นที่สวนสาธารณะกันไหม
# Line 1263: ถ้าอากาศดี พรุ่งนี้เราจะไปปิกนิกที่สวนสาธารณะกันไหม
#
# Cosine similarity: 0.90
# Line 68: แม้ว่าจะเป็นเรื่องยาก แต่ถ้าเราพยายามอย่างเต็มที่ ก็ไม่มีอะไรที่เป็นไปไม่ได้
# Line 1347: งานนี้ยากกว่าที่คิดไว้มาก แต่เราต้องพยายามทำให้ดีที่สุด
#
# Cosine similarity: 0.90
# Line 1074: ถ้าเราทำงานร่วมกัน เราก็จะสามารถบรรลุเป้าหมายได้เร็วขึ้น
# Line 1285: ฉันหวังว่าเราจะสามารถทำงานร่วมกันได้เพื่อเป้าหมายที่ยิ่งใหญ่กว่า
#
# Cosine similarity: 0.90
# Line 692: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
# Line 924: การร่วมมือกันในทีมทำให้เราสามารถบรรลุเป้าหมายที่ใหญ่ขึ้นได้เร็วกว่า
#
# Cosine similarity: 0.90
# Line 924: การร่วมมือกันในทีมทำให้เราสามารถบรรลุเป้าหมายที่ใหญ่ขึ้นได้เร็วกว่า
# Line 1975: ถ้าเราช่วยกันทำงานนี้ เราจะเสร็จเร็วขึ้น
#
# Cosine similarity: 0.90
# Line 699: การฟังเพลงช่วยให้ฉันผ่อนคลายหลังจากวันที่ยาวนาน
# Line 1863: เมื่อฉันเครียด ฉันชอบฟังเพลงเพื่อผ่อนคลาย
#
# Cosine similarity: 0.90
# Line 1761: คุณครูวิทยาศาสตร์สอนให้เรารู้จักสังเกตธรรมชาติ และทำการทดลองอย่างปลอดภัย
# Line 1784: คุณครูวิทยาศาสตร์สอนให้เรารักษาสิ่งแวดล้อม และทำโครงงานเกี่ยวกับการรีไซเคิล
#
# Cosine similarity: 0.90
# Line 639: แม้ว่าจะมีอุปสรรค แต่ฉันเชื่อว่าเราจะร่วมมือกันผ่านมันไปได้
# Line 1831: ถึงแม้ว่าจะมีปัญหา แต่เราก็สามารถแก้ไขได้ด้วยกัน
